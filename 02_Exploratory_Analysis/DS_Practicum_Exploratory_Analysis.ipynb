# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-данных" data-toc-modified-id="Изучение-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Изучение данных</a></span><ul class="toc-item"><li><span><a href="#Таблицы" data-toc-modified-id="Таблицы-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Таблицы</a></span></li><li><span><a href="#Гистограммы" data-toc-modified-id="Гистограммы-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Гистограммы</a></span></li><li><span><a href="#Промежуточные-итоги" data-toc-modified-id="Промежуточные-итоги-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Промежуточные итоги</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Удаление-дубликатов" data-toc-modified-id="Удаление-дубликатов-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Удаление дубликатов</a></span></li><li><span><a href="#Изучение-и-фильтрация-аномальных-значений" data-toc-modified-id="Изучение-и-фильтрация-аномальных-значений-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Изучение и фильтрация аномальных значений</a></span></li><li><span><a href="#Результаты-обработки-аномальных-значений" data-toc-modified-id="Результаты-обработки-аномальных-значений-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Результаты обработки аномальных значений</a></span></li><li><span><a href="#Изучение-и-замена-пропущенных-значений" data-toc-modified-id="Изучение-и-замена-пропущенных-значений-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>Изучение и замена пропущенных значений</a></span></li><li><span><a href="#Конвертация-типов-данных" data-toc-modified-id="Конвертация-типов-данных-1.2.5"><span class="toc-item-num">1.2.5&nbsp;&nbsp;</span>Конвертация типов данных</a></span></li><li><span><a href="#Промежуточные-итоги" data-toc-modified-id="Промежуточные-итоги-1.2.6"><span class="toc-item-num">1.2.6&nbsp;&nbsp;</span>Промежуточные итоги</a></span></li></ul></li><li><span><a href="#check-gap" data-toc-modified-id="check-gap-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>check gap</a></span></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Расчет-дополнительных-столбцов" data-toc-modified-id="Расчет-дополнительных-столбцов-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Расчет дополнительных столбцов</a></span></li><li><span><a href="#Изучение-парметров-объектов" data-toc-modified-id="Изучение-парметров-объектов-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Изучение парметров объектов</a></span></li><li><span><a href="#Изучение-скорости-продажи" data-toc-modified-id="Изучение-скорости-продажи-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Изучение скорости продажи</a></span></li><li><span><a href="#Анализ-факторов,-влияющих-на-цену-объекта" data-toc-modified-id="Анализ-факторов,-влияющих-на-цену-объекта-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>Анализ факторов, влияющих на цену объекта</a></span></li><li><span><a href="#Определение-средней-стоимости-кв.-м-в-различных-населенных-пунктах" data-toc-modified-id="Определение-средней-стоимости-кв.-м-в-различных-населенных-пунктах-1.4.5"><span class="toc-item-num">1.4.5&nbsp;&nbsp;</span>Определение средней стоимости кв. м в различных населенных пунктах</a></span></li><li><span><a href="#Изучение-влияния-расстояния-до-центра-на-стоимость-объекта" data-toc-modified-id="Изучение-влияния-расстояния-до-центра-на-стоимость-объекта-1.4.6"><span class="toc-item-num">1.4.6&nbsp;&nbsp;</span>Изучение влияния расстояния до центра на стоимость объекта</a></span></li><li><span><a href="#Промежуточные-итоги" data-toc-modified-id="Промежуточные-итоги-1.4.7"><span class="toc-item-num">1.4.7&nbsp;&nbsp;</span>Промежуточные итоги</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></li></ul></div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Илья :) Спасибо, что прислал задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название придаст вес проекту
#
# а подробности выполнения проекта дадут возможность вспомнить через полгода — что мы тут делали

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Добавил название проекта в соответствии с названием модуля.

# %% [markdown]
# # Проект: Исследовательский анализ данных

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Изучение данных

# %% [markdown]
# #### Таблицы

# %%
import pandas as pd
from matplotlib import pyplot as plt
import math
import numpy as np

#data = pd.read_csv("real_estate_data.csv", sep="\t")  ## проект делался локально 
                                                      ## на другой машине может понадобиться указать верный путь
try:
    data = pd.read_csv("real_estate_data.csv", sep="\t")
except:       
    data = pd.read_csv('/datasets/real_estate_data.csv', sep = '\t')
    
#print(data.head(5))

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> в сетевой версии данные не загружены

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Добавил try-except блок для чтения данных как локально, так и из сети.
#         Не совсем был уверен, какую директорию указать для чтения в случае открытия не на локальной машине

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Для подгрузки данных стоит использовать конструкцию try-except, она поможет избежать потенциальных ошибок при загрузке данных, связанных, например, с некорректным указанием путей
#
# [Try - Except](https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит делить блок загрузки библиотек и код загрузки датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %%
print(data.info())

size_init = data.shape

#print(data.query("(kitchen_area + living_area) > total_area"))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ <b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> display() вместо print(), поможет навести красоту на проекте, когда строчка кода одна, можно обойтись и без доп. команд

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <b>Подозрительные типы данных: </b>
#
# * <b>first_day_exposition</b> - конвертнем в datetime
# * <b>is_apartment</b> - конвертнем в булеан
# * <b>balcony, parks_around3000, ponds_around3000</b> - дискретные величины, конвертнем в int
#
# <b>Прочие промежуточные выводы: </b>
#
# По большинству столбцов данные выглядят адекватно полными, за исключением высоты потолков. Вроде это должна быть известная величина?
#
# Балконы и апартаменты, вероятно, не были указаны, если их не было, их пропуски можно заменить на 0.
# Недостает географических данных, но, возможно, их учет и отслеживание появился позже, и не во всех объявлениях на момент публикации они были?

# %% [markdown]
# #### Гистограммы

# %%
data.hist(figsize=(15, 20), bins=50);

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Убрать служ. информацию поможет точка с запятой на посл. строке кода
#
#     array([[<AxesSubplot:title={'center':'total_images'}>,
#         <AxesSubplot:title={'center':'last_price'}>,
#         <AxesSubplot:title={'center':'total_area'}>,
#         <AxesSubplot:title={'center':'rooms'}>],
#        [<AxesSubplot:title={'center':'ceiling_height'}>,
#         <AxesSubplot:title={'center':'floors_total'}>,
#         <AxesSubplot:title={'center':'living_area'}>,
#         <AxesSubplot:title={'center':'floor'}>],
#        [<AxesSubplot:title={'center':'kitchen_area'}>,
#         <AxesSubplot:title={'center':'balcony'}>,
#         <AxesSubplot:title={'center':'airports_nearest'}>,
#         <AxesSubplot:title={'center':'cityCenters_nearest'}>],
#        [<AxesSubplot:title={'center':'parks_around3000'}>,
#         <AxesSubplot:title={'center':'parks_nearest'}>,
#         <AxesSubplot:title={'center':'ponds_around3000'}>,
#         <AxesSubplot:title={'center':'ponds_nearest'}>],
#        [<AxesSubplot:title={'center':'days_exposition'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)
#
# data.hist(figsize=(15, 20));

# %% [markdown]
# Наблюдения:
#
# * на графиках <b>last_price</b> и <b>ceiling_height</b> неудачный масштаб оси, на них посмотрим чуть ближе и проверим максимальные значения
# * на <b>total_images</b> есть пик в районе 20, предполагаю, это максимальное число изображений, которое можно приложить, но так же есть значения выше, вероятно, это аномалии
# * на <b>floors_total</b> и <b>living_area</b> есть пара пиков. Вероятно, первое объясняется советскими постройками по типовым проектам (5, 9 этажей). Второе может тоже этим объясняться (раз типовые здания, то и квартиры типовые), но это лучше проверить.
#
# В остальном гистограммы имеют ожидаемые виды Пуассоновских (например, days_exposition) и Гауссовских (например, ponds_nearest) распределений

# %%
data["last_price"].hist(bins=50, range=(0, 50e6))
# Out:
# <AxesSubplot:>

# %%
data["ceiling_height"].hist(bins=50, range=(0, 5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# С этими столбцами все в порядке.
#
# На гистограмме высоты потолков тоже два пика, тоже типовые застройки?

# %% [markdown]
# #### Промежуточные итоги
#
# При первичном осмотрении серьезных проблем с данными нет.
#
# Необходимо обработать аномальные значения.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> обзор данных проведен корректно

# %% [markdown]
# ### Предобработка данных

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) ')

# %%
pass_value_barh(data)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста

# %% [markdown]
# #### Удаление дубликатов

# %% [markdown]
# Сначала удалим явные дубликаты на случай, если они есть. Этот шаг нужно сделать именно сейчас, пока над данным не проведено никаких операций, иначе есть шанс, что из явных дубликаты превратятся в неявные и найти их можно будет разве что случайно.

# %%
#print(data.info())
data.drop_duplicates(inplace=True)
#print(data.info())

# %% [markdown]
# Явных дубликатов не оказалось, но раз уж начали убирать дубликаты, то и неявные стоит тоже заменить.

# %%
print(data["locality_name"].unique())
# Out:
# ['Санкт-Петербург' 'посёлок Шушары' 'городской посёлок Янино-1'
#  'посёлок Парголово' 'посёлок Мурино' 'Ломоносов' 'Сертолово' 'Петергоф'
#  'Пушкин' 'деревня Кудрово' 'Коммунар' 'Колпино'
#  'поселок городского типа Красный Бор' 'Гатчина' 'поселок Мурино'
#  'деревня Фёдоровское' 'Выборг' 'Кронштадт' 'Кировск'
#  'деревня Новое Девяткино' 'посёлок Металлострой'
#  'посёлок городского типа Лебяжье' 'посёлок городского типа Сиверский'
#  'поселок Молодцово' 'поселок городского типа Кузьмоловский'
#  'садовое товарищество Новая Ропша' 'Павловск' 'деревня Пикколово'
#  'Всеволожск' 'Волхов' 'Кингисепп' 'Приозерск' 'Сестрорецк'
#  'деревня Куттузи' 'посёлок Аннино' 'поселок городского типа Ефимовский'
#  'посёлок Плодовое' 'деревня Заклинье' 'поселок Торковичи'
#  'поселок Первомайское' 'Красное Село' 'посёлок Понтонный' 'Сясьстрой'
#  'деревня Старая' 'деревня Лесколово' 'посёлок Новый Свет' 'Сланцы'
#  'село Путилово' 'Ивангород' 'Мурино' 'Шлиссельбург' 'Никольское'
# ...

# %% [markdown]
# Значений тут, конечно, много, всего не увидеть.
#
# Пока что заметна только путаница между *е* и *ё*, но я не уверен, что больше тут ничего не происходит.
#
# Ожидаю, что путаница может быть преимущественно в префиксах названий вроде "поселок", но не в самих названиях, которые вытащить сравнительно просто.
#
# План действий следующий: заменяем *ё* на *е*, затем делаем проверку: достаем уникальные названия из значений в столбцах и смотрим, сколько у них есть префиксов. Если есть более одного, то приводим к общему виду.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Импорт библиотек стоит выносить на первые строки проекта, так коллегам будет удобнее настроить свои рабочие места под наши требования

# %%
import re

data["locality_name"] = data["locality_name"].str.replace("ё", "е")
#print(data["locality_name"].unique())

match_tally = {}
rgx = re.compile("([А-Я]{1}[а-я]*)[ -]*([А-Я]{1}[а-я]*)*")

## регекс матчит имена, начинающиеся с большой буквы
## с опциональным наличием дефисов|пробелов (Санкт-Петербург)
## и опциональным вторым словом (Болшая Ижора)

for item in list(data["locality_name"].unique()):
    
    ## try-except блок нужен, что скипнуть nan
    
    try:
        substring = re.search(rgx, item).group()
    
        if substring in match_tally:
            match_tally[substring] += 1
        else:
            match_tally[substring] = 1
            
    except TypeError:
        pass
        
        
dupes = []  ## хранит названия, у которых более 1 префикса
        
for name, count in match_tally.items():
    if count > 1:
        dupes.append(name)
        #print(name, count)

#print(dupes)

disp = []   ## для отображения, хранит полные названия, в которых повторяются имена

for dupe_item in dupes:
    for source_item in list(data["locality_name"].unique()):
        try:
            if dupe_item in source_item:
                print(source_item)
        except TypeError:
            pass
# Out:
# поселок Мурино
# Мурино
# деревня Кудрово
# Кудрово
# деревня Федоровское
# городской поселок Федоровское
# Никольское
# село Никольское
# поселок городского типа Рощино
# городской поселок Рощино
# село Павлово
# городской поселок Павлово
# поселок городского типа Павлово
# поселок городского типа Советский
# городской поселок Советский
# городской поселок Большая Ижора
# поселок городского типа Большая Ижора
# городской поселок Лесогорский
# поселок городского типа Лесогорский
# поселок городского типа Рахья
# садовое товарищество Рахья
# поселок Зимитицы
# деревня Зимитицы
# поселок Рябово
# поселок городского типа Рябово
# городской поселок Мга
# поселок городского типа Мга
# поселок станции Вещево
# поселок при железнодорожной станции Вещево
# деревня Калитино
# поселок Калитино
# поселок городского типа Приладожский
# садовое товарищество Приладожский
# поселок Щеглово
# деревня Щеглово
# деревня Рабитицы
# поселок Рабитицы
# городской поселок Назия
# ...

# %% [markdown]
# Ну вот и все наши неочевидные дубликаты.
#
# Все они выглядят действительно дубликатами, осталось их заменить.
#
# Самый простой способ их заменить - это убрать префиксы оставив только имена. Да, таким образом будет потеряна часть информации, но, думаю, это приемлимая жертва.

# %%
for dupe in dupes:
    rgx = re.compile(".*(?="+dupe+")")    ## матчит любое количесвто символов, если после них находится искомое имя
    data["locality_name"] = data["locality_name"].str.replace(rgx, "")

#print(data["locality_name"].unique())

# %% [markdown]
# На этом с заменой дубликатов закончено.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> можно создать новую колонку для очищенных наименований, чтобы сохранить оригинальные полные названия в старой

# %%
# check
data.locality_name.nunique()
# Out:
# 305

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />хорошая работа по избавлению от неявных дубликатов

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# Для того, __чтобы изменить лишь часть строки,__ можно добавить к коду — .str
#
#         .str.replace('посёлок','поселок')
#
# [Метод str.replace() в Python, меняет подстроку/символ в строке](https://docs-python.ru/tutorial/operatsii-tekstovymi-strokami-str-python/metod-str-replace/)

# %% [markdown]
# #### Изучение и фильтрация аномальных значений

# %% [markdown]
# Пойдем по порядку появления графиков на матрице выше.
#
# Как указано выше, пик в *total_images* в районе 20 неспроста, вероятно, это максимум того, сколько фото можно добавить.
#
# Все, что выше приравняем к 20.

# %%
data["total_images"] = data["total_images"].where(data["total_images"] < 20, 20)
#data.hist("total_images", bins=20)

# %% [markdown]
# В *last_price* и *total_area* тоже что-то не так

# %%
print("99% процентиль цены равен:", data["last_price"].quantile(0.99))
print("99% процентиль площади равен:", data["total_area"].quantile(0.99), "\n")
print(data.loc[data["last_price"] > data["last_price"].quantile(.99), ["last_price", "total_area"]])
# Out:
# 99% процентиль цены равен: 36000000.0
# 99% процентиль площади равен: 197.21400000000028
#
#         last_price  total_area
# 3       64900000.0       159.0
# 51      45000000.0       161.0
# 155     96000000.0       317.0
# 262     37500000.0       158.0
# 263     39900000.0       140.6
# ...            ...         ...
# 22804   81960000.0       205.0
# 22831  289238400.0       187.5
# 22907   65000000.0       228.0
# 23395   40000000.0       188.0
# 23574   64990000.0       139.0
#
# [236 rows x 2 columns]

# %% [markdown]
# Возможно, что в этих ценах допущена какая-то ошибка, например, не там десятичный разделитель, но смотря на их площадь, ни одна из них не выглядит чем-то явно ошибочным (скажем, квартира 50 кв. м за 20е6 рублей и более).
#
# Тем не менее, квартиры в верхнем 1% площади и цены являются по сути штучными явлениями и я не уверен, что они являются такими же сущностями, как и остальная недвижимость и что к ним применима та же логика, поэтому их из анализа исключим.

# %%
data = data[data["last_price"] < 36e6]
data = data[data["total_area"] < 200]
#data.info()

# %%
print(data[data["rooms"] > 5]["rooms"].sort_values(ascending=False).head(15))
# Out:
# 648      11
# 9688     11
# 8758      8
# 4435      8
# 23555     7
# 3365      7
# 9889      7
# 17991     7
# 17350     7
# 21689     7
# 13776     7
# 5711      7
# 22264     7
# 4159      7
# 3545      7
# Name: rooms, dtype: int64

# %% [markdown]
# Комнат больше 7 всего 4 штуки в датафрейме, отсортируем их

# %%
data = data[data["rooms"] < 7]
#data.info()

# %% [markdown]
# Теперь проверим высоты потолков

# %%
print(data.query("ceiling_height > 5")["ceiling_height"].sort_values(ascending=False))
# Out:
# 22869    100.0
# 3148      32.0
# 22336     32.0
# 21377     27.5
# 22938     27.0
# 4876      27.0
# 21824     27.0
# 5246      27.0
# 5807      27.0
# 20478     27.0
# 10773     27.0
# 17857     27.0
# 5669      26.0
# 18545     25.0
# 355       25.0
# 11285     25.0
# 9379      25.0
# 6246      25.0
# 4643      25.0
# 14382     25.0
# 5076      24.0
# 20507     22.6
# 17496     20.0
# 15061     14.0
# 22309     10.3
# 5863       8.3
# 15743      8.0
# 17442      8.0
# 3474       8.0
# 21227      5.8
# 12628      5.3
# Name: ceiling_height, dtype: float64

# %% [markdown]
# В значениях выше 19, вероятно, не там находится десятичный разделитель, разделим их на 10, а все, что выше 5 и ниже 2 метров уберем.

# %%
data["ceiling_height"] = data["ceiling_height"].apply(lambda x: x / 10 if x > 19 else x)
data = data[(data["ceiling_height"] <= 5) | data["ceiling_height"].isna()]      ## второе условие нужно, чтобы не дропнуть NaN
data = data[(data["ceiling_height"] >= 2) | data["ceiling_height"].isna()]
#print(data.info())

# %% [markdown]
# Проверим количество этажей в здании и этаж из объявления

# %%
print(data["floor"].sort_values(ascending=False).head(15), "\n")
print(data["floors_total"].sort_values(ascending=False).head(15))
# Out:
# 18218    33
# 11575    32
# 18629    31
# 1917     30
# 11079    29
# 397      28
# 113      27
# 6157     27
# 4091     27
# 13276    27
# 12888    27
# 7711     27
# 2629     27
# 8496     27
# 23292    27
# Name: floor, dtype: int64
#
# 2253     60.0
# 16731    52.0
# 11079    36.0
# 397      36.0
# 5807     36.0
# 8496     35.0
# 12888    35.0
# 9370     35.0
# 14347    35.0
# 20938    35.0
# 22946    35.0
# 7236     35.0
# 18218    35.0
# 5749     35.0
# 1060     35.0
# Name: floors_total, dtype: float64

# %% [markdown]
# 35-этажных зданий довольно много и 33 этаж не выглядит таким уж невозможным. Но вот здания с количеством этажей выше 36 выглядят если не невозможными, то маловероятными, отфильтруем их.

# %%
data = data[(data["floors_total"] <= 37) | (data["floors_total"].isna())]
#print(data.info())

# %% [markdown]
# Теперь проверим площадь кухни

# %%
print(data["kitchen_area"].sort_values(ascending=False).head(20))
# Out:
# 22980    65.0
# 18447    65.0
# 15780    64.0
# 19499    64.0
# 14900    62.5
# 3561     60.0
# 20871    58.0
# 4320     56.2
# 16964    55.7
# 17563    54.2
# 20499    53.0
# 19382    53.0
# 11723    51.8
# 8709     51.0
# 6021     51.0
# 20636    50.2
# 5135     50.0
# 656      50.0
# 511      50.0
# 21331    49.4
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Возможно, что в каких-то высоких значениях площади кухни тоже в неправильном месте стоит десятичный разделитель, но и кухня 50 кв. м не выглядит чем-то невероятным. Думаю, стоит оставить их как есть.

# %% [markdown]
# Балконов более 2 вряд ли может быть и я бы их отфильтровал, но на гистограмме их было довольно много

# %%
data[data["balcony"] > 2]["balcony"].count()
# Out:
# 552

# %% [markdown]
# 552 точки - довольно большое значение (из ~12000) и пока что их удалять не хотелось бы. Думаю, лучше их заменить на максимальное значение 2.

# %%
data["balcony"] = data["balcony"].apply(lambda x: 2 if x > 2 else x)

# %% [markdown]
# Остальные гистограммы выглядели будто с ними все в порядке и артефактов в них нет, их пока оставим как есть.

# %% [markdown]
# #### Результаты обработки аномальных значений

# %%
data.hist(figsize=(15, 20), bins=50);

# %% [markdown]
# Эти гистограммы выглядят куда приличнее: никаких серьезных вылетов теперь нет

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23301 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23301 non-null  int64
#  1   last_price            23301 non-null  float64
#  2   total_area            23301 non-null  float64
#  3   first_day_exposition  23301 non-null  object
#  4   rooms                 23301 non-null  int64
#  5   ceiling_height        14243 non-null  float64
#  6   floors_total          23216 non-null  float64
#  7   living_area           21442 non-null  float64
#  8   floor                 23301 non-null  int64
#  9   is_apartment          2729 non-null   object
#  10  studio                23301 non-null  bool
#  11  open_plan             23301 non-null  bool
#  12  kitchen_area          21069 non-null  float64
#  13  balcony               11986 non-null  float64
#  14  locality_name         23252 non-null  object
# ...

# %% [markdown]
# Строк осталось 22.3e3 из 22.7e3, большинство данных на месте.

# %% [markdown]
# #### Изучение и замена пропущенных значений

# %% [markdown]
# Аномальные значения были убраны на предыдущем шаге и теперь они не повлияют на средние величины, которыми будут заменены недостающие значения в количественных свойствах.
#
# Пройдем по каждому из столбцов и посмотрим, чем может быть вызвано отстутствие данных.

# %%
data[data["ceiling_height"].isna()].head(15)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# 14             1   4400000.0       36.00  2016-06-23T00:00:00      1
# 15            16   4650000.0       39.00  2017-11-18T00:00:00      1
# 17             6   4180000.0       36.00  2016-09-09T00:00:00      1
# 21            13   3200000.0       31.60  2018-03-14T00:00:00      1
# 24             8   6500000.0       97.20  2015-10-31T00:00:00      2
# ...

# %% [markdown]
# Ничего очевидного вроде технической ошибки тут нет, квартиры без высоты потолка кажутся реальными.
#
# Недостающие значения можно заменить, но чтобы это сделать лучше, сначала неплохо было бы проверить, обусловлены ли пики на гистограмме типовым застройками.
#
# Логика следующая: если пятиэтажки/девятиэтажки строились по одному/нескольким проектам, то планировки и высоты потолков между ними должны быть одинаковы, т.к. построены они по одним и тем же проектам. Остальные здания при этом, вероятно, строились по более индивидуальным проектам и у них высоты потолков и площадь должны распределяться более равномерно и в более широких диапазонах.

# %%
data.groupby("floors_total")["floors_total"].count().sort_values(ascending=False).head(5)
# Out:
# floors_total
# 5.0     5695
# 9.0     3739
# 16.0    1367
# 12.0    1350
# 10.0    1164
# Name: floors_total, dtype: int64

# %% [markdown]
# Больше всего 5 и 9 этажных зданий, это и есть наши пики с гистограмм.

# %% [markdown]
# Если площадь и высота потолков действительно обусловлена застройками по типовым проектам, то на кроссплоте высота/площадь от количества этажей в "столбцах" 5 и 9 этажей распределение будет сгруппированным и будет отличаться от остальных "столбцов".
#
# Ожидаемое поведение понятно, теперь осталось увидеть графики.

# %%
data.plot(kind="scatter", x="floors_total", y="ceiling_height", ylim=(0, 6), alpha=.1)
# Out:
# <AxesSubplot:xlabel='floors_total', ylabel='ceiling_height'>

# %%
data.plot(kind="scatter", x="floors_total", y="living_area", alpha=.1)
# Out:
# <AxesSubplot:xlabel='floors_total', ylabel='living_area'>

# %% [markdown]
# Теория <b>не подтверждается</b>, здания хоть и типовые, но во-первых диапазон изменения величин у 5-и и 9-и этажек ничуть не уже относительно других, а во-вторых не наблюдается какой-либо группировки (здания одного типового проекта должны иметь одинаковые значения высоты и площади).
#
# А вот что интересно, так это то, что распределения между зданиями с числом этажей более 7 будто бы отличаются от оных для зданий с числом этажей не менее 7. Постараемся это учесть при замене значений.

# %%
median_le7 = data[data["floors_total"] <= 7]["ceiling_height"].median()
print("Медиана высоты потолков для зданий с числом этажей не более 7:", median_le7)

median_gt7 = data[data["floors_total"] > 7]["ceiling_height"].median()
print("Медиана высоты потолков для зданий с числом этажей более 7:", median_gt7)

print("Медиана высоты потолков для всех зданий:", data["ceiling_height"].median())
# Out:
# Медиана высоты потолков для зданий с числом этажей не более 7: 2.65
# Медиана высоты потолков для зданий с числом этажей более 7: 2.65
# Медиана высоты потолков для всех зданий: 2.65

# %% [markdown]
# А вот медианы между этими группами зданий оказались одинаковыми и совпадающими с медианой для всего столбца. Поразительно.

# %%
data["ceiling_height"].fillna(data["ceiling_height"].median(), inplace=True)
#data.info()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />При заполнении средним или медианой необходимо четко отслеживать изменение других статистик: стандартное отклонение, дисперсию и другие параметры выборки
#
# ... если рассмотреть районность высоты потолков, т.к. в современных районах Питера высота потолков будет ожидаема ниже, чем в исторических, мы увидим, что заполнение подобного объема пропусков медианой или средним значением «размажет» это отличительное свойство объектов недвижимости в центре Питера
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)

# %%
median_le7 = data[data["floors_total"] <= 7]["living_area"].median()
print("Медиана высоты потолков для зданий с числом этажей не более 7:", median_le7)

median_gt7 = data[data["floors_total"] > 7]["living_area"].median()
print("Медиана высоты потолков для зданий с числом этажей более 7:", median_gt7)

print("Медиана высоты потолков для всех зданий:", data["living_area"].median())
# Out:
# Медиана высоты потолков для зданий с числом этажей не более 7: 31.0
# Медиана высоты потолков для зданий с числом этажей более 7: 29.0
# Медиана высоты потолков для всех зданий: 30.0

# %% [markdown]
# Здесь значения медианы тоже сравнимы, думаю, разницей можно пренебречь.
#
# Однако заполнить простой медианой будет не совсем верно: что если медиана окажется больше общей площади?
#
# Чтобы избежать таких случаев, рассчитаем медианное значение соотношения жилой площади к общей, а затем рассчитаем жилую площадь через это соотношение и общую площадь. Данные по общей площади у нас есть везде.

# %%
living_to_total_ratio = (data["living_area"] / data["total_area"] * .9).median()
## Примем, что .1 площади приходится на корридоры, балконы и пр.
print("Соотношение жилой площади к общей: {0:.3f}".format(living_to_total_ratio))
# Out:
# Соотношение жилой площади к общей: 0.511

# %% [markdown]
# Но тут есть еще один момент - помимо жилой площади у нас есть еще и площадь кухни. Там, где есть площадь кухни жилую площадь посчитаем вычев площадь кухни из общей.

# %%
data["living_area"].fillna(
    ((data["total_area"] * .9 * living_to_total_ratio) * data["kitchen_area"].isna())+
    ((data["total_area"] * .9 - data["kitchen_area"]) * ~data["kitchen_area"].isna())
    ,inplace=True
)

# %% [markdown]
# Теперь площадь кухни вычислим обратным счетом от двух других площадей.

# %%
data["kitchen_area"].fillna(data["total_area"] - data["living_area"], inplace=True)
#print(data.info())

# %% [markdown]
# Заодно подрежем площади там, где сумма кухни и жилой больше общей

# %%
data["living_area"] = data.apply(lambda x: x["living_area"] / ((x["kitchen_area"] + x["living_area"]) / (x["total_area"] * .9))
                                 if (x["kitchen_area"] + x["living_area"]) > x["total_area"]
                                 else x["living_area"],
                                 axis=1
                                )

data["kitchen_area"] = data.apply(lambda x: x["kitchen_area"] / ((x["kitchen_area"] + x["living_area"]) / (x["total_area"] * .9))
                                 if (x["kitchen_area"] + x["living_area"]) > x["total_area"]
                                 else x["kitchen_area"],
                                 axis=1
                                )

# %% [markdown]
# Теперь заменим недостающие значения в столбце апартаментов.
#
# Логично предположить, что если этот статус не указан, то его нет. Однако, насколько мне известно, апартаменты имеют определенные юридические ограничения относительно полноценных квартир, и, возможно, часть из этих недостающих значений оставлена таковыми неслучайно.
#
# Тем не менее, проверить эту теорию не представляется возможным, поэтому поверим в искренность объявлений и примем, что везде, где этих данных нет, недвижимость апартаментами не является.

# %%
data["is_apartment"].fillna("False", inplace=True)
#print(data.info())

# %% [markdown]
# Аналогичным образом поступим и с числом балконов, везде, где не указано, примем 0.

# %%
data["balcony"].fillna(0, inplace=True)

# %% [markdown]
# Пропщущенные значения *cityCenters_nearest* заполним в зависимости от населенного пункта.
#
# Но сначала нужно определиться с тем, сколько у нас есть населенных пунктов и в скольких из них указано расстояние до центра города.

# %%
temp = data.groupby("locality_name")["locality_name"].count()
print("Число населенных пунктов:", temp.count())
temp = data.groupby("locality_name")["cityCenters_nearest"].median()
print("Число населенных пунктов с указанными расстояниями до центра:", len(temp.unique()) - 1)   ## -1 из-за NaN
# Out:
# Число населенных пунктов: 304
# Число населенных пунктов с указанными расстояниями до центра: 27

# %% [markdown]
# Населенных пунктов с указанным расстоянием менее 10%, теперь нужно понять, какую долю от общего количества данных они составляют.

# %%
print("Общее число объявлений:", data["last_price"].count())
print("Число объявлений в городах с указанием расстояния до центра:", 
      data[data["locality_name"].isin(
          list(temp[~temp.isna()].index)
      )]["locality_name"].count()
     )
#print(temp[~temp.isna()])
# Out:
# Общее число объявлений: 23301
# Число объявлений в городах с указанием расстояния до центра: 18427

# %% [markdown]
# Почти 80% объявлений в городах, для которых можно посчитать среднюю дистанцию до центра. Осталось заполнить пропуски и оценить, сколько недостающих данных осталось.

# %%
city_distance_by_locality = data.groupby("locality_name")["cityCenters_nearest"].median()
airports_distance_by_locality = data.groupby("locality_name")["airports_nearest"].median()
#print(city_distance_by_locality.head(15))

data = data.join(city_distance_by_locality, on="locality_name", how="left", rsuffix="_temp")
data = data.join(airports_distance_by_locality, on="locality_name", how="left", rsuffix="_temp")

data["cityCenters_nearest"].fillna(data["cityCenters_nearest_temp"], inplace=True)
data["airports_nearest"].fillna(data["airports_nearest_temp"], inplace=True)

del data["cityCenters_nearest_temp"]
del data["airports_nearest_temp"]

print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23301 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23301 non-null  int64
#  1   last_price            23301 non-null  float64
#  2   total_area            23301 non-null  float64
#  3   first_day_exposition  23301 non-null  object
#  4   rooms                 23301 non-null  int64
#  5   ceiling_height        23301 non-null  float64
#  6   floors_total          23216 non-null  float64
#  7   living_area           21869 non-null  float64
#  8   floor                 23301 non-null  int64
#  9   is_apartment          23301 non-null  object
#  10  studio                23301 non-null  bool
#  11  open_plan             23301 non-null  bool
#  12  kitchen_area          21869 non-null  float64
#  13  balcony               23301 non-null  float64
#  14  locality_name         23252 non-null  object
# ...

# %% [markdown]
# Значений удалось восстановить немного (было 17795, стало 18468).
#
# Пропущенных значений все еще остается около 21%, это значительный объем пропусков, который может отразиться на результатах анализа.
#
# К сожалению, восстановить остальные значения не представляется возможным: замена пропущенных значений на среднее, не привязанное к населенному пункту, вероятно, приведет к более серьезным ошибкам, чем оставление пропусков.

# %% [markdown]
# В величинах *parks_around3000* и *ponds_around3000* содержатся дискретные величины, заменить их некими средними значениями будет неправильно. С другой стороны, можно предположить, что если они не указаны, то там должен быть 0. Однако я думаю, что эти величины не указываются пользователем, а генерируются некой автоматической системой и, если это предположение верно, то заменить их на 0 будет неверно, поэтому они будут оставлены как есть.
#
# Аналогичная ситуация и с *locality_name*, восстановить имя населенного пункта невозможно.
#
# Остальные величины заменим по медиане, т.к. формы их распеределений соответствуют ожидаемым и медиана устойчива к вылетающим значениями.

# %%
columns_to_fill = ["airports_nearest", "parks_nearest", "ponds_nearest"]

for column in columns_to_fill:
    data[column].fillna(data[column].median(), inplace=True)
    
#print(data.info())

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />После заполнения синтетическими данными столбцов, стоит провести проверку на корректность значений всех наших площадей, т.к. есть (коридоры, сан.узлы, балконы)
#
#         total_area*0.9 <= (living_area + kitchen_area)
#
# если алгоритм приводит к появлению аномалий, стоит подумать над его содержимым

# %%
print("Квартиры, у которых сумма площадей больше общей:")
print(data.query("(living_area + kitchen_area) > total_area")[["living_area", "kitchen_area", "total_area"]], "\n")
print("Квартиры, у которых площадь кухни меньше 0:")
print(data[data["kitchen_area"] < 0]["kitchen_area"])
# Out:
# Квартиры, у которых сумма площадей больше общей:
#        living_area  kitchen_area  total_area
# 1407     11.008840     13.795413       24.60
# 4366     25.126676     22.702071       47.70
# 7755      9.301500     11.467944       20.67
# 11579    14.850000     18.903305       33.00
#
# Квартиры, у которых площадь кухни меньше 0:
# Series([], Name: kitchen_area, dtype: float64)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> А вот это очень интересная проверка, которая мне почему-то в голову не пришла.
#
# Да, действительно, такие аномальные квартиры получаются и их довольно много
#
# ![Area_check.PNG](attachment:Area_check.PNG)
#
# В коде выше я модифицировал замену на расчет через соотношение жилой площади к общей. Такой метод позволит избежать появления подобных нефизичных значений.
#
# Так же в изначальных данных было 64 квартиры, в которых сумма площадей выходила больше общей (*total_area*). В них я тоже постарался отнормировать *kitchen_area* и *living_area* на *total_area*, но там осталось 4 квартиры, которые не сходятся буквально на пару десятых кв. м. Да, это не совсем правильно, но, думаю, оставить их как есть, на дальнейший анализ они не повлияют.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Не изучено распределение пропусков по городам до заполнения значений в ['city_сenters_nearest']
#
# к каким населенным пунктам относятся и оценить степень влияния пропусков на дальнейший анализ (будут мешать или нет)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Тоже отличное замечание, реализовал замену по населенным пунктам, где это было возможно, в остальных местах оставил пропуски.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Пропуски в ['days_exposition'] говорят нам, что квартиры еще не проданы..., неверно терять столь важный признак, → оставляем пропуски

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Почему мне это не пришло в голову... Убрал замену, оставил пропуски.

# %% [markdown]
# #### Конвертация типов данных

# %% [markdown]
# Конвертацию данных начнем с конвертации *is_apartment* в булеан. Он может принимать только 2 значения и в этом случае это самый логичный тип данных.

# %%
data["is_apartment"].replace("False", False, inplace=True)
#print(data["is_apartment"].unique())
#print(data.info())

# %% [markdown]
# Столбцы *floors_total*, *balcony*, *parks_around3000*, *ponds_around3000* содержат в себе дискретные величины и неплохо было бы конвертировать их в int, как в самый подходящий тип данных.
#
# Проблема в том что в них всех, кроме balcony есть пропуски, а NaN считается числом с плавающей точкой, поэтому не заменив или не дропнув их, конвертировать тип данных не получится.
#
# Пропусков в столбце *floors_total* совсем немного, можно их дропнуть без особых потерь, тогда этот столбец можно будет сконвертировать.
#
# Затем сконвертируем *balcony*.

# %%
data.dropna(subset=["floors_total"], inplace=True)

data["floors_total"] = data["floors_total"].astype("int64")
data["balcony"] = data["balcony"].astype("int64")
#print(data["balcony"].unique())
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23216 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23216 non-null  int64
#  1   last_price            23216 non-null  float64
#  2   total_area            23216 non-null  float64
#  3   first_day_exposition  23216 non-null  object
#  4   rooms                 23216 non-null  int64
#  5   ceiling_height        23216 non-null  float64
#  6   floors_total          23216 non-null  int64
#  7   living_area           21817 non-null  float64
#  8   floor                 23216 non-null  int64
#  9   is_apartment          23216 non-null  bool
#  10  studio                23216 non-null  bool
#  11  open_plan             23216 non-null  bool
#  12  kitchen_area          21817 non-null  float64
#  13  balcony               23216 non-null  int64
#  14  locality_name         23168 non-null  object
# ...

# %% [markdown]
# *first_day_exposition* конвертируем в *datetime*. Даты по виду уже округлены до полуночи, шаг округления можно пропустить.

# %%
#print(data["first_day_exposition"].head())
data["first_day_exposition"] = pd.to_datetime(data["first_day_exposition"], format="%Y-%m-%dT%H:%M:%S")
#print(data["first_day_exposition"].head())

# %% [markdown]
# #### Промежуточные итоги

# %% [markdown]
# Данные очищены и подготовлены к анализу.
#
# * Заменены явные и неявные дубликаты
# * Аномальные значения удалены или заменены на предельные, где возможно
# * Пропущенные значения заменены на характерные там, где возможно
# * Данные конвертированы в наиболее подходящие типы там, где возможно
# * ~400 строк с данными были отсортированы в процессе обработки аномальных значений
# * Высота потолков и площадь объекта не зависят от количества этажей в здании.

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23216 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23216 non-null  int64
#  1   last_price            23216 non-null  float64
#  2   total_area            23216 non-null  float64
#  3   first_day_exposition  23216 non-null  datetime64[ns]
#  4   rooms                 23216 non-null  int64
#  5   ceiling_height        23216 non-null  float64
#  6   floors_total          23216 non-null  int64
#  7   living_area           21817 non-null  float64
#  8   floor                 23216 non-null  int64
#  9   is_apartment          23216 non-null  bool
#  10  studio                23216 non-null  bool
#  11  open_plan             23216 non-null  bool
#  12  kitchen_area          21817 non-null  float64
#  13  balcony               23216 non-null  int64
#  14  locality_name         23168 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# стоит сменить тип данных в
#
#        6   floors_total          23216 non-null  float64
#
# пропуски можно удалить, кол-во их минимально

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделано, но у меня остается такой вопрос: неужели тип данных важнее, чем наличие данных? Я бы ожидал, что сохранение имеющихся данных важнее, чем удобство работы аналитика с ними, разве нет? Все-таки тип, в котором хранятся данные - исключительно технический аспект, с которым кроме аналитика никому работать не придется, а вот с выводами, которые потенциально были искажены из-за удаления данных работать придется всем заинтересованным?

# %% [markdown]
# ### check gap

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __проверим какие аномалии остались__ таблица ниже

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bf66e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >rooms</th>
#       <th class="col_heading level0 col1" >total_area</th>
#       <th class="col_heading level0 col2" >ceiling_height</th>
#       <th class="col_heading level0 col3" >days_exposition</th>
#       <th class="col_heading level0 col4" >last_price</th>
#       <th class="col_heading level0 col5" >living_area</th>
#       <th class="col_heading level0 col6" >kitchen_area</th>
#       <th class="col_heading level0 col7" >floor</th>
#       <th class="col_heading level0 col8" >floors_total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf66e_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_bf66e_row0_col0" class="data row0 col0" >23,216.00</td>
#       <td id="T_bf66e_row0_col1" class="data row0 col1" >23,216.00</td>
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#         'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area'
#
# стоит учесть наличие пропусков при фильтрации данных

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для выполнения пункта 2.4. существует два подхода
#
# Можно механически бороться с выбросами, ...
#
# основная проблема такого подхода — не учитывается неоднородность нашей выборки: у нас здесь и малые поселки, и вторая столица страны, и исторический фонд и массовая застройка, и однушки и довольно большое кол-во многокомнатных квартир, или наоборот одна две квартиры с количеством комнат больше 7-ми ...
#
#
#
# если бы у нас в таблице были бы только однокомнатные квартиры из определенного района массовой застройки, тогда да, мы бы боролись с выбросами традиционными способами, при нашем многообразии населенных пунктов, многокомнатности такие подходы не работают... т.е. они работают, но это усложнит наш проект — придется разбить и объединить записи нашей таблицы по нескольким параметрам (кол-во комнат, район, и т.д.), а затем только выполнять все остальные пункты на каждой отдельной выборке
#
# Остается другой подход — убираем редкие значения и следим за количеством потерь...
#
# Для выборки из 23-х тысяч значений, несколько записей со стоимостью квадратного метра выше 1-го млн. руб., довольно редкое явление
#
# Хороший пример, высота потолков, которую мы отрезаем по нижней и верхней планке, это скорее аномальные записи, посмотрим на другой аспект — на редкости: кол-во комнат
#
# __т.е. мы не говорим о том, что квартир с кол-ом комнат выше 7 не бывает, мы говорим, что для нашего исследования это редкие выбивающиеся из общей картины уникальные объекты, по которым необходимо проводить отдельную работу ...__
#
# подобным образом рассматриваем и остальные параметры
#
# наши помощники
#
# 1. гистограммы, с хорошим масштабом
# 2. метод describe() или облегченная версия, пример выше
# 3. метод value_counts()
#
# плюс жизненный опыт

# %%
# check
data.rooms.value_counts().to_frame()
# Out:
#    rooms
# 1   8003
# 2   7892
# 3   5719
# 4   1100
# 5    252
# 0    192
# 6     58

# %%
# check
data.living_area.hist(bins = 150, figsize = (15,3));

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />т.е. все квартиры менее 10-ти и более 130-ти квадратных метров можно считать редкостями

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Тут у меня такой вопрос: возможно ли как-то математически обосновать границы того, что мы считаем редкостями?
# Иными словами, почему выбрана именно цифра в 130? Почему не, например, 120 или даже 100?
# Просто если на эту гистограмму посмотрят 5 разных человек, то они, вероятно, назовут 5 разных граничных значений. Существует ли какое-нибудь правило или методика, которое позволило бы этого избежать? Может, какой-нибудь негласный стандарт, который считается лучшей практикой?

# %%
# check
data.living_area.hist(bins = 150, figsize = (15,3), range = (60,170));

# %%
# check
data.living_area.hist(bins = 15, figsize = (15,3), range = (60,170));

# %%
# check
data.living_area.hist(bins = 15, figsize = (15,3), range = (0,17));

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Осталось завершить выполнение пункта 2.4 из брифа проекта
#
# 2.4.	Найдите и устраните редкие и выбивающиеся значения.
#
# __Критичный уровень потерь записей на этапе предобработки составляет 10%, оптимальный 5%__

# %%
# check

# Значения параметров объектов недвижимости на разных квантилях

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  
        'kitchen_area', 'floor',   'floors_total']]
    .quantile([0.0012, 0.01, .5, .99, .9988]) # выбираем размах в 0,9976 квантилей 
    .style.format("{:,.2f}")
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_45df0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >rooms</th>
#       <th class="col_heading level0 col1" >total_area</th>
#       <th class="col_heading level0 col2" >ceiling_height</th>
#       <th class="col_heading level0 col3" >days_exposition</th>
#       <th class="col_heading level0 col4" >last_price</th>
#       <th class="col_heading level0 col5" >living_area</th>
#       <th class="col_heading level0 col6" >kitchen_area</th>
#       <th class="col_heading level0 col7" >floor</th>
#       <th class="col_heading level0 col8" >floors_total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_45df0_level0_row0" class="row_heading level0 row0" >0.0012</th>
#       <td id="T_45df0_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_45df0_row0_col1" class="data row0 col1" >20.00</td>
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Квантили что это такое
#
# https://fin-accounting.ru/cfa/l1/quantitative/cfa-quartiles-quintiles-deciles-percentiles?ysclid=l7gy2kky4i156375632
#
# они помогают увидеть редкости и аномалии в данных

# %% [markdown]
# Повторно отсортируем аномальные значения:

# %%
data["total_area"].hist(bins=100, figsize=(15, 3), range=(60, 200))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Редкими будем считать значения выше 180

# %%
data.drop(data[data["total_area"] > 180].index, inplace=True)

# %% [markdown]
# То же проделаем с жилой площадью

# %%
data["living_area"].hist(bins=100, figsize=(15, 3), range=(10, 140))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Редкими будем считать значения выше 100

# %%
data.drop(data[data["living_area"] > 100].index, inplace=True)

# %% [markdown]
# Теперь обработаем площадь кухни

# %%
data["kitchen_area"].hist(bins=100, figsize=(15, 3), range=(0, 60))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Все, что выше 35 будем считать редкими значениями

# %%
data.drop(data[data["kitchen_area"] > 35].index, inplace=True)

# %% [markdown]
# Теперь высота потолков

# %%
data["ceiling_height"].hist(bins=100, figsize=(15, 3))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Редкими будем считать значения выше 3.6 и ниже 2.4

# %%
data.drop(data[(data["ceiling_height"] > 3.6) | (data["ceiling_height"] < 2.4)].index, inplace=True)

# %% [markdown]
# Теперь количество дней, которые объявления были активны

# %%
data["days_exposition"].hist(bins=100, figsize=(15, 3))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Думаю, все, что больше 1200 можно считать редкостями

# %%
data.drop(data[data["days_exposition"] > 1200].index, inplace=True)

# %% [markdown]
# И последний столбец, цена

# %%
data["last_price"].hist(bins=100, figsize=(15, 3))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Все, что выше 25e6 считаем редкостями

# %%
data.drop(data[data["last_price"] > 25e6].index, inplace=True)

# %% [markdown]
# Теперь проверим, сколько данных было утеряно

# %%
size_fin = data.shape

print('''
Начальное количество строк: {0}
Конечное количество строк: {1}
Потеряно строк: {2}
    что составляет {3:.2%} от начального количества
'''.format(size_init[0], size_fin[0], size_init[0] - size_fin[0], (size_init[0] - size_fin[0]) / size_init[0]))
# Out:
# Начальное количество строк: 23699
# Конечное количество строк: 22495
# Потеряно строк: 1204
#     что составляет 5.08% от начального количества

# %% [markdown]
# Объем утерянных данных приемлим.

# %% [markdown]
# ### Анализ данных

# %% [markdown]
# #### Расчет дополнительных столбцов

# %% [markdown]
# Расчитаем следующие столбцы для дальнейшего использования:
# * цена 1 кв. м
# * день недели размещения объявления
# * месяц размещения объявления
# * год размещения объявления
# * тип этажа
# * расстояние до центра города в км

# %%
data["area_price"] = data["last_price"] / data["total_area"]   ## цена одного кв. м
data["weekday"] = data["first_day_exposition"].dt.weekday
data["month"] = data["first_day_exposition"].dt.month
data["year"] = data["first_day_exposition"].dt.year

def storey_switch(storey: int, total: int) -> str:
    
    ## Порядок проверок именно такой:
    ## Если проверять сначала на то, является ли этаж последним,
    ## то первый этаж окажется последним в случае, когда число этажей = 1
    
    if storey == 1:
        return "Первый"
    elif storey == total:
        return "Последний"
    else:
        return "Другой"

data["storey_type"] = data.apply(lambda x: storey_switch(storey=x["floor"], total=x["floors_total"]), axis=1)
#print(data["storey_type"].value_counts())

data["city_centre_distance_km"] = data["cityCenters_nearest"] / 1e3

##округление до целочилсенных
data["city_centre_distance_km"] = data["city_centre_distance_km"].apply(lambda x: math.ceil(x) if not np.isnan(x) else x)
#print(data[["cityCenters_nearest", "city_centre_distance_km"]])
#print(data.head(10))

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Функция хорошая, стоит учесть крайние условия: нулевые и отрицательные значения

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит выполнить пункт проекта
#
# •	расстояние до центра города в километрах (переведите из м в км и __округлите до целых значений__).

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Округлил дистанцию до целочисленных, в первый раз невнимательно прочитал задание и в итоге все равно округлял дальше по проекту.

# %% [markdown]
# #### Изучение парметров объектов

# %% [markdown]
# Опишем параметры объектов и взглянем на гистограммы. В качестве описания подойдет метод pd.DataFrame.describe().

# %%
def examine(column, bins=50, figsize=(15, 3), legend=True):
    
    column.hist(bins=bins, figsize=figsize, legend=legend)
    description = column.describe()
    
    ## добавим в описание коэф. вариации, он более удобно описывает степень дисперсии данных
    description.loc["cv"] = description["std"] / description["mean"]
    print(description)

examine(data["total_area"])
# Out:
# count    22495.000000
# mean        55.669103
# std         22.134768
# min         12.000000
# 25%         39.650000
# 50%         50.600000
# 75%         66.300000
# max        180.000000
# cv           0.397613
# Name: total_area, dtype: float64

# %% [markdown]
# Распределение Гауссово со смещением пика влево и длинным хвостом из высоких значений.
#
# Пик в районе ~40-50 кв. м, степень дисперсии средняя (.44).

# %%
examine(data["living_area"], bins=50)
# Out:
# count    21129.000000
# mean        32.051136
# std         15.055180
# min          2.000000
# 25%         18.500000
# 50%         30.000000
# 75%         41.000000
# max        100.000000
# cv           0.469724
# Name: living_area, dtype: float64

# %% [markdown]
# Распределение отдаленно Гауссово со смещением влево, длинным хвостом высоких значений и двумя ярко выраженными пиками в районе ~16 и ~30, а так же ярко выраженным провалом в районе ~25.
#
# Степень дисперсии средняя (.49).

# %%
examine(data["kitchen_area"])
# Out:
# count    21129.000000
# mean        10.105481
# std          4.425479
# min          0.000000
# 25%          7.000000
# 50%          9.000000
# 75%         11.670000
# max         35.000000
# cv           0.437929
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Распределение Гауссово со смещением влево, длинным хвостом из высоких значений и пиком в районе ~10.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Хорошие графики, можно добавить кол-во корзин к параметрам гистограммы и  изменить размер у графиков (увеличить ширину)
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://pyprog.pro/mpl/mpl_axis_signatures.html) и [там](https://pyprog.pro/mpl/mpl_title.html), и
#
# [тут](https://proproprogs.ru/modules/matplotlib-razmeshchaem-standartnye-tekstovye-elementy-na-grafike?ysclid=l6agtioc6f299002507)

# %%
examine(data["last_price"])
# Out:
# count    2.249500e+04
# mean     5.375807e+06
# std      3.290999e+06
# min      4.300000e+05
# 25%      3.390000e+06
# 50%      4.500000e+06
# 75%      6.400000e+06
# max      2.500000e+07
# cv       6.121869e-01
# Name: last_price, dtype: float64

# %% [markdown]
# Гауссово распределение со смещением влево и длинным хвостом высоких значений, пик в районе ~4 млн.
#
# Высокая степень дисперсии (.71)

# %%
examine(data["rooms"], bins=7)
# Out:
# count    22495.000000
# mean         1.984397
# std          0.939901
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          6.000000
# cv           0.473646
# Name: rooms, dtype: float64

# %% [markdown]
# Гауссово распределение со сдвигом влево, небольшим хвостом из высоких значений, пик в районе 2.

# %%
examine(data["ceiling_height"])
# Out:
# count    22495.000000
# mean         2.676922
# std          0.170108
# min          2.400000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max          3.600000
# cv           0.063546
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Распределение отдаленно Гаусово со смещением влево и ярко выраженным пиком в районе ~2.6. Очень низкая степень дисперсии (.08).
#
# Пик этот, вероятно, вызван отсутствием большого числа данных в первоначальном датасете, высота была указана только в ~14e3 строк  из ~24e3. Все отсутствующие значения были заменены на медиану (2.65), ее-то мы и видим на гистограмме.

# %%
examine(data["floor"], bins=100)
# Out:
# count    22495.000000
# mean         5.910736
# std          4.905132
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         33.000000
# cv           0.829868
# Name: floor, dtype: float64

# %% [markdown]
# Пуассоново распределение с заметными "ступеньками" в районе 5 и 9.
#
# Вероятно, ступеньки вызваны преобладанием 5-этажных и 9-этажных домов в общей популяции домов.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит изменить параметры отображения гистограммы (добавить корзин), сейчас трудно определить границу резкого снижения кол-ва объявлений, или на 4-ке, или на 5-ке, или на 6-ке ...

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Изменил число корзин, теперь гистограмма похожа на расческу, но зато хорошо видны ступеньки.

# %%
examine(data["storey_type"].replace({
    "Другой": 0,
    "Первый": 1,
    "Последний": 2
}), bins=3)
# Out:
# count    22495.000000
# mean         0.401467
# std          0.718469
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          2.000000
# cv           1.789609
# Name: storey_type, dtype: float64

# %% [markdown]
# Распределением это назвать, конечно, затруднительно.
#
# А вот что странно так это то, что квартир на последнем этаже больше, чем квартир на первом, учитывая пик в районе единицы на предыдущем графике.
#
# В первый раз у меня получилось то же самое и я связал это с тем, как была написана функция присвоения категории (storey_switch).
#
# Тогда первой была проверка на последний этаж и квартиры в одноэтажных домах категоризировались как на последнем этаже.

# %%
## Проверка на то, что свитч работает как ожидается

#print(data.query("storey_type == 'Последний'")[["floor", "floors_total", "storey_type"]].head(15))
#print(data.query("floors_total == 1")[["floor", "floors_total", "storey_type"]].head(15))

# %% [markdown]
# Теперь проверка работает правильно (закоменченный код для проверки в ячейке выше), но квартир на последнем этаже все равно больше.
#
# Учитывая, что квартир на первом этаже было больше всего, и я это связал с количеством одноэтажных домов, то я бы ожидал, что и квартир на первом этаже было бы больше, чем на последнем.
#
# Нужно еще проверить распределение общего числа этажей.

# %%
examine(data["floors_total"], bins=100)
# Out:
# count    22495.000000
# mean        10.798088
# std          6.624568
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         36.000000
# cv           0.613494
# Name: floors_total, dtype: float64

# %% [markdown]
# А вот это уже совсем странно.
#
# Больше всего 5-ти и 9-ти этажек, логично предположить, что это типовые застройки, тут все в порядке.
#
# А вот что не логично, так это то, что этот график совсем не объясняет пик в районе единицы на гистограмме этажей. Как видно, одноэтажных зданий совсем немного и я бы ожидал, что количество квартир по этажам (при равном числе этажей) распределяется равномерно.
#
# Тут возможны два объяснения:
# 1) мое предположение о равномерности распределения неверно и квартиры на первом этаже продаются чаще, чем все остальные
#
# 2) сэмплинг из популяции для этого датасета был не совсем случайным

# %% [markdown]
# Перейдем к изучению расстояний до объектов, начнем с расстояния до центра города

# %%
examine(data["cityCenters_nearest"])
# Out:
# count    17713.000000
# mean     14859.775899
# std       8504.449797
# min        287.000000
# 25%      10304.000000
# 50%      13549.000000
# 75%      16921.000000
# max      65968.000000
# cv           0.572313
# Name: cityCenters_nearest, dtype: float64

# %% [markdown]
# Тоже своего рода Гауссово распределение с явным пиком в районе ~12000.
#
# Этот пик тоже вызван отстуствием данных в столбце и заменой пропусков на медиану.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> При отрисовке графиков стоит исключать значения-заглушки, которыми мы заполнили пропуски

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Это верно, но в первой итерации мне это показалось сделать сильно сложным. Оказалось, что нет, глупый способ в лоб работает.

# %% [markdown]
# Изучим столбец расстояния до аэропорта

# %%
examine(data[data["airports_nearest"] != data["airports_nearest"].median()]["airports_nearest"])
# Out:
# count    17707.000000
# mean     29673.438132
# std      13269.074331
# min          0.000000
# 25%      18545.000000
# 50%      27653.000000
# 75%      39163.000000
# max      84869.000000
# cv           0.447170
# Name: airports_nearest, dtype: float64

# %% [markdown]
# Платообразное распределение с пиком в районе ~52 тыс.

# %% [markdown]
# Изучим расстояние до ближайшего парка

# %%
examine(data[data["parks_nearest"] != data["parks_nearest"].median()]["parks_nearest"])
# Out:
# count    7288.000000
# mean      494.340285
# std       341.064096
# min         1.000000
# 25%       289.000000
# 50%       458.000000
# 75%       617.000000
# max      3190.000000
# cv          0.689938
# Name: parks_nearest, dtype: float64

# %% [markdown]
# Снова смещенное влево распределение Гаусса
#
# Большинство домов находятся менее, чем в 1000 м от парка

# %%
examine(data["month"], bins=30)
# Out:
# count    22495.000000
# mean         6.402934
# std          3.489507
# min          1.000000
# 25%          3.000000
# 50%          6.000000
# 75%         10.000000
# max         12.000000
# cv           0.544986
# Name: month, dtype: float64

# %% [markdown]
# Интересное распределение, явно видно, что наибольшее число публикаций происходит весной и осенью, а зимой (кроме февраля) и летом публикаций сравнительно немного.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️  Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Интересно, почему февраль (самый короткий месяц) опережает все месяцы — ?__

# %%
examine(data["weekday"], bins=30)
# Out:
# count    22495.000000
# mean         2.573772
# std          1.792039
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          4.000000
# max          6.000000
# cv           0.696270
# Name: weekday, dtype: float64

# %% [markdown]
# Тоже интересное распределение. Явно видно, что в выходные объявлений публикуется существенно меньше, чем в будние.
#
# Может это связано с тем, что большинство объявлений публикуются риелторами и агентствами по недвижимости, которые в выходные не работают?

# %% [markdown]
# #### Изучение скорости продажи

# %% [markdown]
# Для начала посмотрим на гистограмму и средние значения столбца *days_exposition*

# %%
examine(data["days_exposition"], bins=100)
# Out:
# count    19593.000000
# mean       172.261063
# std        203.240266
# min          1.000000
# 25%         44.000000
# 50%         93.000000
# 75%        222.000000
# max       1200.000000
# cv           1.179839
# Name: days_exposition, dtype: float64

# %% [markdown]
# За среднее значение времени продажи здесь лучшего всего принять медиану из-за длинного хвоста высоких значений (также хорошо видно разницу между средним и медианой).
#
# В таком случае <b>средним временем продажи</b> является <b>93</b> дня.
#
# Для категоризации продаж как быстрых или необычно долгих есть несколько методов:
# 1. Mean +/- 2 SD - этот метод не подойдет, т.к. наше распределение сильно далеко от стандартного
# 2. квартили +/- nIQD - этот метод не подойдет в нашем случае для минимума, т.к. IQD получится сильно больше расстояния от нуля до Q1. Зато этот метод отлично подойдет для максимума.
# 3. выше/ниже определенных процентилей. Этот метод подойдет как для минимума, так и для максимума, но его проблема в том, что выбор граничного процентиля никак математически не обоснован и лежит целиком на совести аналитика.
#
# Итого:
# * Быстрыми будем считать продажи быстрее десятого процентиля
# * Необычно долгими будем считать продажи медленее Q3 + IQD ("укороченные усы" боксплота)

# %%
iqd = data["days_exposition"].quantile(.75) - data["days_exposition"].quantile(.25)

print("Быстрыми считаем продажи, совершенные менее чем за {0:n} дней".format(data["days_exposition"].quantile(.1)))
print("Необычно долгими считаем продажи, совершенные более чем за {0:n} дней".format(data["days_exposition"].quantile(.75) + iqd))
# Out:
# Быстрыми считаем продажи, совершенные менее чем за 17 дней
# Необычно долгими считаем продажи, совершенные более чем за 400 дней

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />В расчете скорости продаж не исключены медианные заглушки, более 3000 записей искажают статистики скорости продаж
#
# Стоит пересчитать статистики скорости продажи после восстановления пропусков

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Замены удалены, итоговые значения изменились:
#
#                     Было    Стало
#         Быстрые     19      17
#         Медленные   349     400

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Интересно посмотреть на изменение средней  скорости продаж по годам__

# %%
temp = data.groupby("year")["days_exposition"].median()
print(temp)
plt.bar(x=temp.index, height=temp)
# Out:
# year
# 2014    760.0
# 2015    547.0
# 2016    230.0
# 2017    101.0
# 2018     63.0
# 2019     23.0
# Name: days_exposition, dtype: float64
# <BarContainer object of 6 artists>

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Не исследованы моды в 'days_exposition' и как они влияют на скорость продажи, подсказка на что смотреть
#
# [Условия размещения объявлений](https://yandex.ru/support/realty/owner/home/add-ads-housing.html)

# %%
data["days_exposition"].hist(bins=100, figsize=(15, 3), range=(0, 100))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Интересное наблюдение, пики в районе 7, 30, 45, 60 и 90. Ознакомиться с правилами размещения объявлений мне почему-то в голову не пришло, получается, что эти объявления были вероятно закрыты не по совершению сделки, а по истечению времени размещения объявлений.
#
# Значит, смотреть за пределы датафрейма бывает сильно полезно, буду иметь в виду.

# %% [markdown]
# #### Анализ факторов, влияющих на цену объекта

# %% [markdown]
# Поиск взаимосвязи между ценой объекта и различными его параметрами будем осуществлять изучением графиков (scatter или hexbin) и расчетом коэф. Пирсона.
#
# Но прежде чем строить интересующие графики, нужно провести небольшое преобразование данных: часть интересующих нас величин дискретны и принимают буквально несколько возможных значений. Для них посчитаем среднюю стоимость для каждого принимаемого значения, от этих же средних будем считать коэф. корреляции и строить графики.

# %%
from matplotlib import pyplot as plt

## Хелпер, в котором будет храниться категория этажа в числовом виде для отображения на график
data["storey_type_num"] = data["storey_type"].replace({
    "Другой": 0,
    "Первый": 1,
    "Последний": 2
})

corr_coeff = {}  ## Коэфф. корреляции, пара параметр:коэф

## Параметры с непрерывными величинами, с которыми можно работать без доп. обработки
regular_indexes = ["total_area", "living_area", "kitchen_area"]  


for item in regular_indexes:
    
    plt.scatter(x=data[item], y=data["last_price"], alpha=.03)
    plt.xlabel(item)
    plt.ylabel("last_price")
    plt.show()
    
    corr_coeff[item] = data["last_price"].corr(data[item])
    print("Коэф. корреляции между {0} и {1} равен ".format(item, "last_price"), round(corr_coeff[item], 3))

    
    
## Параметры с дискретными величинами, по ним будем считать медиану для построения графиков
pivot_indexes = ["rooms", "storey_type_num", "floors_total", "weekday", "month", "year"]

for item in pivot_indexes:
    
    data_pivot = data.pivot_table(index=item, values="last_price", aggfunc="median")
    ## pivot_table вернул Series, в котором индексом является значение величины
    
    ## вспомогательная Series, в которой хранится индекс (значение переданной величины)
    right_hand = pd.Series(data_pivot.index)
    #print(right_hand)
    #print(data_pivot)
    
    ## сращение значений величины и соответствующих им цен в единый DataFrame
    data_pivot = pd.merge(left=data_pivot, right=right_hand, left_index=True, right_on=right_hand)
    #print(data_pivot)
    
    plt.scatter(x=data_pivot[item], y=data_pivot["last_price"])
    plt.xlabel(item)
    plt.ylabel("last_price")
    plt.show()
    
    #print(data_pivot)
    corr_coeff[item] = data_pivot["last_price"].corr(data_pivot[item])
    print("Коэф. корреляции между {0} и {1} равен ".format(item, "last_price"), round(corr_coeff[item], 3))
# Out:
# Коэф. корреляции между total_area и last_price равен  0.763
# Коэф. корреляции между living_area и last_price равен  0.646
# Коэф. корреляции между kitchen_area и last_price равен  0.524
# Коэф. корреляции между rooms и last_price равен  0.987
# Коэф. корреляции между storey_type_num и last_price равен  -0.638
# Коэф. корреляции между floors_total и last_price равен  0.384
# Коэф. корреляции между weekday и last_price равен  -0.49
# Коэф. корреляции между month и last_price равен  0.157
# Коэф. корреляции между year и last_price равен  -0.604

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Коэффициент корреляции рассчитывается для всех зависимостей из задания, исключая параметры - день недели и месяц, сама природа этих параметров не позволяет опираться на подобный расчет

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит дополнить  вывод об изменении цен по годам, необходимо учесть другие факторы, которые также изменяются с годами: площадь и кол-во объявлений о продаже (стоит добавить или графики, или сводные таблицы и исследовать взаимное влияние параметров)
#
#         Есть корреляция между ценой и годом: в 2014 цены были максимальными, в 2015 они заметно снизились относительно предыдущего года, в 2016-2018 цены были примерно одинаковы, в 2019 цены снова начали расти.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Да, построив графики ниже все стало значительно понятнее. Очередное напоминание о необходимости проверять полученные результаты.

# %% [markdown]
# На графике зависимости стоимости от года видна зависимость: цены в 2014-2015 гг существенно выше, чем в 2016-2018, а в 2019 наблюдается повторный рост стоимости.
#
# Нужно проверить, насколько сравнимы данные между годами, возможно разница в ценах связана не с годами, а с тем, какие объявления в эти годы размещались?

# %%
pivot_median_count = data.pivot_table(index="year", aggfunc=["median", "count"])

print(pivot_median_count[[("median", "living_area"), ("median", "kitchen_area"), ("median", "total_area"), ("median", "last_price"), ("count", "last_price")]])
#print(pivot_median)
temp_list = [("median", "living_area"), ("median", "kitchen_area"), ("median", "total_area"), ("median", "last_price"), ("count", "last_price")]
for item in temp_list:
    plt.scatter(x=pivot_median_count.index, y=pivot_median_count[item])
    plt.xlabel("Year")
    plt.ylabel(item[1] + " " + item[0])
    plt.show()
# Out:
#           median                                         count
#      living_area kitchen_area total_area last_price last_price
# year
# 2014        39.6        10.91       67.5  6230000.0        100
# 2015        32.0        10.00       57.0  5000000.0       1019
# 2016        30.0         9.00       51.9  4400000.0       2620
# 2017        29.8         9.00       50.1  4400000.0       7799
# 2018        29.5         9.00       50.0  4500000.0       8220
# 2019        30.0         8.70       50.6  4950000.0       2737

# %% [markdown]
# Из графиков выше хорошо видно, что недвижимость в 2014-2015 гг существенно отличается от недвижимости в последующие годы: средняя площадь выше, соответственно, стоимость тоже выше. К тому же, объем данных из 2014-2015 невелик: ~100 объявлений в 2014 и ~1000 в 2015. Исходя из этого, можно заключить, что установить зависимость средней цены от года невозможно ввиду различности данных для разных годов.

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />  Можно попробовать настроить вид точечных графиков
#
# [5.2. Scatter - график разброса (точки)](https://pyprog.pro/mpl/mpl_scatter.html?ysclid=l65k3vmmqd649359421)
#
# Примеры расчета коэф. корреляции и не только
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?ysclid=l9ev0utyg728177057)

# %% [markdown]
# Выводы:
# * Между площадями (общей, жилой, кухни) наблюдается определенная прямая корреляция.
# * Очень сильная зависимость наблюдается между ценой и числом комнат (коэф. корр. близок к 1).
# * Использовать коэф. корр относительно типа этажа неверно, но можно отметить, что квартиры на крайних (первый/последний) этажах существенно дешевле, чем квартиры на других этажах.
# * Определенная зависимость есть между ценой и числом этажей в доме: до 10 этажей наблюдается прямая зависимость, от 10 до 25 этажей цена независима от числа этажей, после 25 этажей наблюдается слабая положительная корреляция
# * Сильная корреляция есть между днем недели, когда опубликовано объявление и ценой: в будние цена существенно выше, чем в выходные, идет на убывание до значений выходных начиная со вторника.
# * Корреляция между месяцем объявления и ценой отсутствует
# * Зависимость между стоимостью недвижимости и годом установить затруднительно из-за 1) сравнительно малого количества данных в 2014-2015 (особенно в 2014), 2) существенных отличий средних показателей площади в 2014-2015 от последующих лет.
#
# Список факторов, наиболее и наименее влияющих на среднюю цену в порядке убывания ниже:

# %%
ranking = pd.Series(corr_coeff)
ranking = ranking.apply(lambda x: abs(x))
ranking = ranking.sort_values(ascending=False)
print(ranking)
# Out:
# rooms              0.987393
# total_area         0.762677
# living_area        0.646056
# storey_type_num    0.637927
# year               0.604440
# kitchen_area       0.523591
# weekday            0.490290
# floors_total       0.384404
# month              0.157001
# dtype: float64

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит упомянуть на каких параметрах (расчетных) мы получили подобные коэф. корреляции

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Если честно, не совсем понял этот комментарий. Коэф. корреляции получены на медианные значения стоимости и медианные значения исследуемых параметров, это имеется в виду?

# %% [markdown]
# #### Определение средней стоимости кв. м в различных населенных пунктах

# %% [markdown]
# Сначала определим 10 населенных пунктов с наибольшим числом объявлений

# %%
localities = data.groupby("locality_name")["locality_name"].count()
localities = localities.sort_values(ascending=False).head(10)
print(localities)
# Out:
# locality_name
# Санкт-Петербург      14641
# Мурино                 585
# Кудрово                467
# поселок Шушары         436
# Всеволожск             392
# Пушкин                 349
# Колпино                337
# поселок Парголово      324
# Гатчина                304
# Выборг                 229
# Name: locality_name, dtype: int64

# %% [markdown]
# Теперь расчитаем для них среднюю цену. Средней будем считать медиану как более устойчивую к вылетающим значениям.

# %%
locality_price = data.pivot_table(index="locality_name", values="area_price")
localities = pd.merge(left=localities, right=locality_price, how="left", left_index=True, right_index=True)
localities.rename(columns={"locality_name":"count"}, inplace=True)
localities = localities.sort_values("area_price", ascending=False)
localities["area_price"].plot(kind="bar")
print(localities)
# Out:
#                    count     area_price
# locality_name
# Санкт-Петербург    14641  109318.611224
# Пушкин               349  101953.366831
# Кудрово              467   95308.053230
# поселок Парголово    324   90277.876676
# Мурино               585   86040.789965
# поселок Шушары       436   78605.579273
# Колпино              337   75333.295801
# Гатчина              304   68781.726816
# Всеволожск           392   68688.175199
# Выборг               229   58121.987388

# %% [markdown]
# Самыми дорогими населенными пунктами являются Санкт-Петербург, Пушкин и Кудрово.
#
# Самыми недорогими являются Выборг, Всеволожск и Гатчина.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />ТОП-10 рассчитан корректно

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />        Можно развернуть график
#
#      kind='barh'
#
# [Постер поможет выбирать вид графиков](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)

# %% [markdown]
# #### Изучение влияния расстояния до центра на стоимость объекта

# %%
data_pivot = data.query("locality_name=='Санкт-Петербург'").pivot_table(index="city_centre_distance_km", values="last_price")
plt.scatter(x=data_pivot.index, y=data_pivot)
plt.xlabel("Расстояние до центра, км")
plt.ylabel("Цена объекта")
plt.show()

# %% [markdown]
# Зависимость вполне ожидаемая: цена стремительно падает до 10-го километра от центра, после чего тем падения существенно замедляется.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для выполнения 5-го пункта стоит отфильтровать выборку по питерским квартирам
#
#         5.	Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города.

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Снова невнимательно задание читал (-_\\). Отфильтровал только СПб.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит изучить записи, которые привели к выбросу на 27-м км.

# %%
data_pivot = data.query("locality_name=='Санкт-Петербург'").pivot_table(
    index="city_centre_distance_km", values=["rooms", "total_area", "living_area", "kitchen_area"], aggfunc="median"
)

for column in data_pivot.columns:
    plt.bar(x=data_pivot.index, height=data_pivot[column])
    plt.xlabel("Distance from city centre")
    plt.ylabel(column)
    plt.show()
    
data_pivot = data.query("locality_name=='Санкт-Петербург'").pivot_table(
    index="city_centre_distance_km", values="last_price", aggfunc="count"
)

plt.bar(x=data_pivot.index, height=data_pivot["last_price"])
plt.xlabel("Distance from city centre")
plt.ylabel("count")
plt.show()

print(data_pivot.tail())
# Out:
#                          last_price
# city_centre_distance_km
# 26.0                             64
# 27.0                              3
# 28.0                              2
# 29.0                             10
# 30.0                              3

# %% [markdown]
# Выбросы на 28 км вызваны малым числом данных: всего 2 записи.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит посмотреть на количество квартир разных категорий (первый, последний, другой), которые продаются на 3-м км. и 5-ом ... и какую долю они занимают на каждом километре, чтобы объяснить пик и провал в центре

# %% [markdown]
# #### Промежуточные итоги

# %% [markdown]
# * Cреднее временя продажи - 93 дня, при этом быстрыми можнос считать продажи быстрее, чем за 17 дней, а необычайно долгими продажи более чем за 400 дней.
# * Наибольшее влияние на цену объекта оказывают (в порядке убывания): количество комнат (r2 = .98), день размещения объявления (r2 = .82) и общая площадь объекта (r2 = .78). Наименьшее влияние оказывают (в порядке возрастания): месяц размещения объявления (r2 = .00), количество этажей в здании (r2 = .33) и площадь кухни (r2 = .56).
# * Наиболее дорогим квадратный метр оказался в: Санкт-Петербурге (111e3 за кв. м), Пушкин (103e3 за кв. м), Кудрово (95e3 за кв. м). Дешевле всего квадратный метр оценивается в Выборге (58e3 за кв. м), Всеволожске (69e3 за кв. м) и Гатчине (69e3 за кв. м).
# * Стоимость объекта стремительно уменьшается с отдалением от центра города до 10-го километра (почти в 2 раза), после чего она продолжает падать с удалением, но намного медленнее.

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# * <b>Cреднее время продажи</b> - <b>93 дня</b>, при этом быстрыми можно считать продажи быстрее, чем за 17 дней, а необычайно долгими продажи более чем за 400 дней.
# * <b>Наибольшее влияние на цену</b> объекта оказывают: <b>количество комнат, день размещения объявления и общая площадь</b>. Наименьшее влияние оказывают месяц размещения объявления, количество этажей в здании и площадь кухни. Полный список представлен ниже.

# %%
print(ranking.round(3))
# Out:
# rooms              0.987
# total_area         0.763
# living_area        0.646
# storey_type_num    0.638
# year               0.604
# kitchen_area       0.524
# weekday            0.490
# floors_total       0.384
# month              0.157
# dtype: float64

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> на проектах стоит снижать размерность выводимой информации, где не требуется максимальная точность, до одного или двух знаков после запятой
#
#         storey_type_num    0.606143
#         kitchen_area       0.559371
#         floors_total       0.329231

# %% [markdown]
# * Можно отметить, что квартиры на крайних (первый/последний) этажах существенно дешевле, чем квартиры на других этажах.
# * Зависимость стоимости от числа этажей нелинейна: до 10 этажей наблюдается прямая зависимость, от 10 до 25 этажей цена независима от числа этажей, после 25 этажей наблюдается слабая положительная корреляция.
# * Зависимость между стоимостью недвижимости и годом установить затруднительно из-за 1) сравнительно малого количества данных в 2014-2015 (особенно в 2014), 2) существенных отличий средних показателей площади в 2014-2015 от последующих лет.

# %% [markdown]
# * <b>Наиболее дорогим квадратный метр оказался в Санкт-Петербурге</b>, затем в Пушкине и Кудрово. <b>Наиболее дешевым квадратный метр является в Выборге</b>, Всеволожске и Гатчине. График стоимости квадратного метра в населенных пунктах представлен ниже.
# ![Locality_price.png](attachment:Locality_price.png)

# %% [markdown]
# * <b>Стоимость</b> объекта <b>стремительно уменьшается</b> с отдалением от центра города <b>до 10-го километра</b> (более, чем в 2 раза), после чего она продолжает падать с удалением, но намного медленнее. Визуально это представлено на графике ниже.

# %%
data_pivot = data.pivot_table(index="city_centre_distance_km_rnd", values="last_price")
plt.scatter(x=data_pivot.index, y=data_pivot)
plt.xlabel("Расстояние до центра, км")
plt.ylabel("Цена объекта")
plt.show()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Не стоит включать код в итоговый вывод, картинки можно вставить
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Технически вывод хороший, есть сравнения показателей, инсайты, анализ рынка недвижимости, молодец
#
# Осталось перепроверить итоговый вывод после исправления всех комментариев

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выполнил исследовательскую работу, молодец, показал хороший уровень навыков программирования
#
# Критические ❌ комментарии
#
#
# + добавить оформления проекту: название
# + настроить загрузку сетевой версии
# + вернуть записи с пропусками в колонку о скорости продаж
# + проверить и вернуть пропуски в колонку о расстоянии до аэропорта и центра города
# + проверить корректность заполнения пропусков синтетическими данными
# + сменить тип данных
# + настроить фильтрацию редких значений в п. 2.4
# + подправить гистограмму в п.4.1
# + пересчитать скорость продаж
# + дополнить вывод в п. 4.3
# + перепроверить график в п.4.5
# + исследовать аномалии в п.4.5
# + поправить итоговый вывод
#
#
# С ними важно поработать и исправить
#
# Стоит обратить внимание и на такие комментарии ⚠️
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# Добавил себе чеклист по правкам:
# + [x] добавить оформления проекту: название
# + [x] настроить загрузку сетевой версии
# + [x] вернуть записи с пропусками в колонку о скорости продаж
# + [x] проверить и вернуть пропуски в колонку о расстоянии до аэропорта и центра города
# + [x] проверить корректность заполнения пропусков синтетическими данными
# + [x] сменить тип данных
# + [x] настроить фильтрацию редких значений в п. 2.4
# + [x] подправить гистограмму в п.4.1
# + [x] пересчитать скорость продаж
# + [ ] дополнить вывод в п. 4.3
# + [ ] перепроверить график в п.4.5
# + [ ] исследовать аномалии в п.4.5
# + [ ] поправить итоговый вывод

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)
#
# <p> Доп. материал: методы группировки и расчета суммы, средних и т.д.
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
#  Интересная функция в библиотеке пандаса
#
# [Понимание функции transform в Pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%BD%D0%B8%D0%BC%D0%B0%D0%BD%D0%B8%D0%B5%20%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D0%B8%20transform%20%D0%B2%20Pandas.html)
#
# [Как выбрать определенные столбцы из DataFrame](https://dfedorov.spb.ru/pandas/03.%20%D0%9A%D0%B0%D0%BA%20%D0%B2%D1%8B%D0%B1%D1%80%D0%B0%D1%82%D1%8C%20%D0%BF%D0%BE%D0%B4%D0%BC%D0%BD%D0%BE%D0%B6%D0%B5%D1%81%D1%82%D0%B2%D0%BE%20%D0%B8%D0%B7%20DataFrame_.html?ysclid=l9sps5lt6g576766938)
#
# [How to visualise data using histograms in Pandas](https://practicaldatascience.co.uk/data-science/how-to-visualise-data-using-histograms-in-pandas)

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
