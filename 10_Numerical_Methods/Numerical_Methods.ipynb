# %% [markdown]
# <div style="background: #91ff7e; padding: 5px; border: 1px solid Black; border-radius: 5px;">
#     КОММЕНТАРИЙ СТУДЕНТА V1
#     <br/>
#     Дуолан, приветствую! <br>
#     Большое спасибо за проверку проекта, комментарии и дополнительные материалы, узнал для себя новое. <br>
#     Я скорректировал проект с учетом замечаний, прошу посмотреть.
# </div>

# %% [markdown]
# Привет, Илья!)
# <br> Меня зовут Дуолан 👋 и я рад стать твоим проводником в мире кода и данных!
# <br> Вместе мы прокачаем твой проект до самого верха! 🚀
# <br> Давай общаться на «ты» и поддерживать дружескую атмосферу. Если ты согласен, конечно! 😊
# <br> Пожалуйста, напиши мне ответ на каждый комментарий («исправлено», «не уверен, как это сделать» и т. д.)
# <br> Оставь, пожалуйста, мои комментарии на месте – они пригодятся для последующих проверок.
#
# Комментарии будут в <font color='green'>зеленой</font>, <font color='blue'>синей</font> или <font color='red'>красной</font> рамках:
#
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b> Если всё просто супер!
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>⚠️ Совет:</b> Если можно немного улучшить
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>❌ Замечание:</b> Если требуются исправления
# </div>
#
# Твой проект не может быть принят, пока есть красные комментарии.
#
# -------------------
#
# Пожалуйста, отмечай свои ответы и изменения таким образом:
#
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b> ...
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Изменения:</b> Вот что я изменил ...
# </div>

# %% [markdown]
# <div style="background: #91ff7e; padding: 5px; border: 1px solid Black; border-radius: 5px;">
#     КОММЕНТАРИЙ СТУДЕНТА
#     <br/>
#     Приветствую, ревьюер! <br>
#     У меня тут такой вопрос - поскольку проект получился относительно долгим в исполнении (~10 минут реального времени на моей машине), на какое время исполнения стоит ориентироваться, чтобы проверяющему было комфортно работать с проектом?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий ревьюера:</b>
#
# Мне понравился твой проект 👍🏻 Видно, что приложено много усилий)
#
# Перед отправкой проекта, пожалуйста, перезапусти ядро и убедись, что весь код работает (Kernel -> Restart and Run All). Важно, чтобы нумерация ячеек была правильной (начиналась с "1" и выполнялась по порядку).
#
# Если не хочешь ждать обучения моделей, можешь сохранить лучшие гиперпараметры в отдельной переменной и закомментировать код. Необходимо также зафиксировать random_state, чтобы результат был всегда одинаковым.
#
# Таким образом, я смогу быстрее проверить проект, и ты успеешь к дедлайну 👋🏻
# </div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-и-осмотр-данных" data-toc-modified-id="Загрузка-и-осмотр-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка и осмотр данных</a></span></li><li><span><a href="#Удаление-дубликатов" data-toc-modified-id="Удаление-дубликатов-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Удаление дубликатов</a></span></li><li><span><a href="#Изучение-данных" data-toc-modified-id="Изучение-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Изучение данных</a></span><ul class="toc-item"><li><span><a href="#Scatter-Matrix" data-toc-modified-id="Scatter-Matrix-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Scatter Matrix</a></span></li><li><span><a href="#Обработка-невозможных-значений" data-toc-modified-id="Обработка-невозможных-значений-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Обработка невозможных значений</a></span></li><li><span><a href="#Повторный-Scatter-Matrix" data-toc-modified-id="Повторный-Scatter-Matrix-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Повторный Scatter Matrix</a></span></li></ul></li><li><span><a href="#Обработка-аномальных-значений" data-toc-modified-id="Обработка-аномальных-значений-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Обработка аномальных значений</a></span></li><li><span><a href="#Заполнение-пропусков" data-toc-modified-id="Заполнение-пропусков-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Заполнение пропусков</a></span></li><li><span><a href="#Выделение-предикторов-и-разделение-на-выборки" data-toc-modified-id="Выделение-предикторов-и-разделение-на-выборки-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Выделение предикторов и разделение на выборки</a></span></li></ul></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Скейлинг-и-кодировка-данных" data-toc-modified-id="Скейлинг-и-кодировка-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Скейлинг и кодировка данных</a></span></li><li><span><a href="#Базовая-модель" data-toc-modified-id="Базовая-модель-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Базовая модель</a></span></li><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Линейная регрессия</a></span></li><li><span><a href="#K-ближайших-соседей" data-toc-modified-id="K-ближайших-соседей-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>K ближайших соседей</a></span></li><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Градиентный-бустинг" data-toc-modified-id="Градиентный-бустинг-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Градиентный бустинг</a></span></li></ul></li><li><span><a href="#Анализ-моделей" data-toc-modified-id="Анализ-моделей-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ моделей</a></span><ul class="toc-item"><li><span><a href="#Сравнение" data-toc-modified-id="Сравнение-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Сравнение</a></span></li><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li><li><span><a href="#Проверка-на-тестовой-выборке" data-toc-modified-id="Проверка-на-тестовой-выборке-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Проверка на тестовой выборке</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# # Определение стоимости автомобилей

# %% [markdown]
# Сервис по продаже автомобилей с пробегом «Не бит, не крашен» разрабатывает приложение для привлечения новых клиентов. В нём можно быстро узнать рыночную стоимость своего автомобиля. В вашем распоряжении исторические данные: технические характеристики, комплектации и цены автомобилей. Вам нужно построить модель для определения стоимости.
#
# Заказчику важны:
#
# - качество предсказания;
# - скорость предсказания;
# - время обучения.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Загрузка и осмотр данных

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt

from lightgbm import LGBMRegressor

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import mean_squared_error, make_scorer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.compose import make_column_transformer
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.dummy import DummyRegressor

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Импорт выглядит отлично 👍
# </div>

# %%
try:
    data = pd.read_csv("autos.csv")
except FileNotFoundError:
    data = pd.read_csv("/datasets/autos.csv")

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        354369 non-null  object
#  1   Price              354369 non-null  int64
#  2   VehicleType        316879 non-null  object
#  3   RegistrationYear   354369 non-null  int64
#  4   Gearbox            334536 non-null  object
#  5   Power              354369 non-null  int64
#  6   Model              334664 non-null  object
#  7   Kilometer          354369 non-null  int64
#  8   RegistrationMonth  354369 non-null  int64
#  9   FuelType           321474 non-null  object
#  10  Brand              354369 non-null  object
#  11  Repaired           283215 non-null  object
#  12  DateCreated        354369 non-null  object
#  13  NumberOfPictures   354369 non-null  int64
#  14  PostalCode         354369 non-null  int64
# ...

# %%
display(data.head())
# Out:
#            DateCrawled  Price VehicleType  RegistrationYear Gearbox  Power  \
# 0  2016-03-24 11:52:17    480         NaN              1993  manual      0
# 1  2016-03-24 10:58:45  18300       coupe              2011  manual    190
# 2  2016-03-14 12:52:21   9800         suv              2004    auto    163
# 3  2016-03-17 16:54:04   1500       small              2001  manual     75
# 4  2016-03-31 17:25:20   3600       small              2008  manual     69
#
#    Model  Kilometer  RegistrationMonth  FuelType       Brand Repaired  \
# 0   golf     150000                  0    petrol  volkswagen      NaN
# 1    NaN     125000                  5  gasoline        audi      yes
# 2  grand     125000                  8  gasoline        jeep      NaN
# 3   golf     150000                  6    petrol  volkswagen       no
# 4  fabia      90000                  7  gasoline       skoda       no
#
#            DateCreated  NumberOfPictures  PostalCode             LastSeen
# ...

# %% [markdown]
# Данные успешно загружены, есть пропуски, часть типов данных стоит конвертировать.
#
# Проверим на дубликаты, пока над данными никаких операций не произведено.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b> 👍
# </div>

# %% [markdown]
# ### Удаление дубликатов

# %%
shape_init = data.shape

# %%
data.drop_duplicates(inplace=True)

# %%
print("Удалено дубликатов:", shape_init[0] - data.shape[0])
# Out:
# Удалено дубликатов: 4

# %% [markdown]
# Явных дубликатов больше нет. Из неявных выглядит так, будто бензиновый тип топлива записывается двумя разными способами.

# %%
print(data["FuelType"].unique())
# Out:
# ['petrol' 'gasoline' nan 'lpg' 'other' 'hybrid' 'cng' 'electric']

# %% [markdown]
# Да, так и есть, petrol и gasoline - оба "бензин". Заменим на один.

# %%
data["FuelType"] = data["FuelType"].str.replace("gasoline", "petrol")

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# От явных дубликатов избавились 👍
# </div>

# %% [markdown]
# ### Изучение данных

# %% [markdown]
# #### Scatter Matrix

# %% [markdown]
# Столбцов не супер много, можно посмотреть на scatter_matrix

# %%
pd.plotting.scatter_matrix(data, figsize=(15, 10), hist_kwds={"bins":50}, alpha=.5);
# Out:
# /home/metal_undivided/anaconda3/envs/practicum/lib/python3.9/site-packages/pandas/plotting/_matplotlib/misc.py:89: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[j])
# /home/metal_undivided/anaconda3/envs/practicum/lib/python3.9/site-packages/pandas/plotting/_matplotlib/misc.py:90: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(boundaries_list[i])
# /home/metal_undivided/anaconda3/envs/practicum/lib/python3.9/site-packages/pandas/plotting/_matplotlib/misc.py:80: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[i])

# %% [markdown]
# Бросаются в глаза невозможные значения года регистрации и мощности двигателя.
#
# Нужно их убрать

# %% [markdown]
# #### Обработка невозможных значений

# %% [markdown]
# Посмотрим, чем могут быть вызваны невозможные значения года

# %%
display(data[(data["RegistrationYear"] > 2016) | (data["RegistrationYear"] < 1900)].head(15))
# Out:
#              DateCrawled  Price VehicleType  RegistrationYear Gearbox  Power  \
# 22   2016-03-23 14:52:51   2900         NaN              2018  manual     90
# 26   2016-03-10 19:38:18   5555         NaN              2017  manual    125
# 48   2016-03-25 14:40:12   7750         NaN              2017  manual     80
# 51   2016-03-07 18:57:08   2000         NaN              2017  manual     90
# 57   2016-03-10 20:53:19   2399         NaN              2018  manual     64
# 65   2016-03-28 17:41:27  10900         NaN              2017  manual    101
# 111  2016-03-19 18:40:12      0         NaN              2017  manual      0
# 155  2016-03-09 12:53:53  14500         NaN              2017  manual    136
# 163  2016-04-04 12:57:02   1200         NaN              2018  manual     75
# 196  2016-03-24 13:51:03   2800         NaN              2018  manual     75
# 218  2016-03-13 18:47:40   2100         NaN              2017  manual      0
# ...

# %% [markdown]
# Эти можно считать NaNами.
#
# Посмотрим, что с мощностью двигателя.

# %%
display(data[data["Power"] > 1000].head(15))
# Out:
#                DateCrawled  Price VehicleType  RegistrationYear Gearbox  \
# 1816   2016-03-22 20:52:00   3200       small              2004  manual
# 2102   2016-03-21 11:55:22      0       sedan              1999     NaN
# 5328   2016-03-29 19:44:48    500       wagon              1999  manual
# 7661   2016-04-02 19:25:25   1499       small              1999  manual
# 7720   2016-04-02 11:48:54   1500       small              2000  manual
# 9664   2016-03-14 20:06:19   2599         NaN              2016  manual
# 9875   2016-03-31 20:51:13    550       wagon              2003  manual
# 11039  2016-03-25 19:55:32      0       sedan              1998  manual
# 19078  2016-03-20 11:00:08      0         NaN              2016  manual
# 19092  2016-03-20 17:54:04   9750       wagon              2005    auto
# 19826  2016-03-18 23:52:30   3390       sedan              2009  manual
# 20050  2016-03-26 19:46:06   2200       sedan              2002    auto
# ...

# %% [markdown]
# Выглядит, будто бы сдвинут десятичный разделитель, при том где-то на один порядок, а где-то и на два.

# %% [markdown]
# Итого:
# - годы до 1900 заменяем на NaNы, после 2016 - ограничиваем 2016
# - для мощности двигаем десятичный разделитель, пока мощность не окажется в диапазоне 65 - 650 л.с. Серийных машин с мощностью более 650 л.с. не так много и, если они и есть, то составляют они малую часть данных. То же самое и с машинами с мощностью менее 65 л.с., все-таки данные из Европы, а не Японии.

# %%
data.loc[(data["RegistrationYear"] < 1900), "RegistrationYear"] = np.NaN

# %%
data.loc[data["RegistrationYear"] > 2016, "RegistrationYear"] = 2016

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌ Замечание:</b>
#
# Год регистрации автомобиля (RegistrationYear) следует ограничить верхней границей 2016 года. Максимально возможный год регистрации должен соответствовать дате скачивания анкеты (DateCrawled) в 2016 году.
# </div>

# %% [markdown]
# <div style="background: #91ff7e; padding: 5px; border: 1px solid Black; border-radius: 5px;">
#     КОММЕНТАРИЙ СТУДЕНТА V1
#     <br/>
#     Да, действительно, данные 2016 года. <br>
#     Несколько изменил логику заполнения: годам до 1900 так же присваиваются NaNы, а вот годы больше 2016, приравниваются к 2016.
# </div>

# %%
HP_LIMIT = 650

while len(data[data["Power"] > HP_LIMIT]) > 0:
    data.loc[data["Power"] > HP_LIMIT, "Power"] = data["Power"] / 10

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Мощность ограничили 👍
# </div>

# %% [markdown]
# #### Повторный Scatter Matrix

# %% [markdown]
# Теперь гистограммы и кроссплоты должны быть в гораздо более разумных пределах, смотрим на scatter_matrix еще раз.

# %%
pd.plotting.scatter_matrix(data, figsize=(15, 10), hist_kwds={"bins":50}, alpha=.5);
# Out:
# /home/metal_undivided/anaconda3/envs/practicum/lib/python3.9/site-packages/pandas/plotting/_matplotlib/misc.py:89: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[j])
# /home/metal_undivided/anaconda3/envs/practicum/lib/python3.9/site-packages/pandas/plotting/_matplotlib/misc.py:90: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(boundaries_list[i])
# /home/metal_undivided/anaconda3/envs/practicum/lib/python3.9/site-packages/pandas/plotting/_matplotlib/misc.py:80: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[i])

# %% [markdown]
# Зависимостей в данных не видно, взглянем поближе на гистограммы.

# %% [markdown]
# ### Обработка аномальных значений

# %%
def numerical_hists(data):
    columns = data.dtypes[data.dtypes != "object"].index

    fig, axs = plt.subplots(len(columns), 1, figsize=(10, 20))

    axi = 0

    for column in columns:
        axs[axi].hist(data[column], bins=50)
        axs[axi].set_title(column)
        axi += 1

# %%
numerical_hists(data)

# %% [markdown]
# Наблюдения:
# - Для цены столбец около нуля подозрительно большой, стоит проверить, нет ли там нулевых значений. Хвост справа я бы критичным не назвал, думаю, оставить его как есть.
# - У года регистрации длинный хвост слева, его обрежем.
# - У мощности двигателя много околонулевых значений и тоже длинный хвост справа, который обрежем.
# - Пробег с дискретностью 15000 км, выглядит достойно, с ним ничего делать не будем.
# - С остальные столбцы выглядят нормально, оставим их как есть.

# %% [markdown]
# Пойдем по порядку, начав с проверки цены на нулевые значения.

# %%
display(data[data["Price"] == 0].shape)
# Out:
# (10772, 16)

# %% [markdown]
# Значения такие есть, заменим их на NaN

# %%
data.loc[data["Price"] == 0, "Price"] = np.NaN

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# В данных остались машины только с адекватной ценой 👍
# </div>

# %% [markdown]
# Дальше год регистрации, там нас интересует нижняя граница.
#
# Удалим нижние 0.1% значений.

# %%
data.drop(data[data["RegistrationYear"] < data["RegistrationYear"].quantile(0.001)].index, inplace=True)

# %% [markdown]
# С мощностью двигателя провернем аналогичный ход, но удалим верхние 0.1% значений и заменим нулевые значения (если есть) на NaN.

# %%
data.drop(data[data["Power"] > data["Power"].quantile(1 - 0.001)].index, inplace=True)

# %%
display(data[data["Power"] == 0].shape)
# Out:
# (40038, 16)

# %%
data.loc[data["Power"] == 0, "Power"] = np.NaN

# %% [markdown]
# Вроде готово, можно повторно проверяться на гистограммах.

# %%
numerical_hists(data)

# %% [markdown]
# Окей, от аномальных значений избавились, теперь нужно заполнить пропуски.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b> 👍
# </div>

# %% [markdown]
# ### Заполнение пропусков

# %% [markdown]
# Еще раз посмотрим, сколько пропусков есть.

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 353693 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        353693 non-null  object
#  1   Price              343002 non-null  float64
#  2   VehicleType        316309 non-null  object
#  3   RegistrationYear   353627 non-null  float64
#  4   Gearbox            333999 non-null  object
#  5   Power              313655 non-null  float64
#  6   Model              334158 non-null  object
#  7   Kilometer          353693 non-null  int64
#  8   RegistrationMonth  353693 non-null  int64
#  9   FuelType           320952 non-null  object
#  10  Brand              353693 non-null  object
#  11  Repaired           282775 non-null  object
#  12  DateCreated        353693 non-null  object
#  13  NumberOfPictures   353693 non-null  int64
#  14  PostalCode         353693 non-null  int64
# ...

# %% [markdown]
# Пропусков много, сбросить их не удастся.
#
# Попробуем заполнить следующим образом:
# 1) для каждой модели авто определим характерные параметры: моды для параметров авто (тип, коробка, топливо и пр.), медианы для непрерывных величин (цена).
# 2) заполним пропуски в зависимости от модели авто в соответствии с таблицей из п. 1.

# %%
data["MakeModel"] = data["Brand"] + "_" + data["Model"]

# %%
cartype_modes = data.pivot_table(
    values=["VehicleType", "Gearbox", "Power", "FuelType"],
    index="MakeModel",
    aggfunc=lambda column: column.mode()
)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Отличный метод 👍
# </div>

# %% [markdown]
# Моды есть, но не везде, там где моду вычислить невозможно, в таблицу попал список.
#
# Выберем из него последний элемент.

# %%
display(cartype_modes[cartype_modes.index == "land_rover_serie_2"])
# Out:
#                    FuelType Gearbox                                   Power  \
# MakeModel
# land_rover_serie_2   petrol  manual  [46.0, 57.0, 69.0, 70.0, 100.0, 109.0]
#
#                      VehicleType
# MakeModel
# land_rover_serie_2  [other, suv]

# %%
def select_last_item(array):
    
    if type(array) == np.ndarray:  ## Если моду рассчитать не получается (все значения уникальны),
                                   ## mode() возвращает список со всеми значениями
        if len(array) > 0:         ## Если по типу авто нет данных (все значения NaN),
            return array[-1]       ## mode() возвращает пустой список
        else:
            return np.NaN
    else:
        return array               ## Если расчет моды удачен и получено одно значение

# %%
cartype_modes["Power"] = cartype_modes["Power"].apply(lambda item: select_last_item(item)).astype("float32")
cartype_modes["VehicleType"] = cartype_modes["VehicleType"].apply(lambda item: select_last_item(item))

# %% [markdown]
# Моды рассчитали, теперь расчитаем медианы для цены и объединим все в одну таблицу

# %%
cartype_medians = data.pivot_table(
    values="Price",
    index="MakeModel",
    aggfunc="median"
)

# %%
cartype_summary = cartype_modes.merge(cartype_medians, how="left", left_index=True, right_index=True)

# %% [markdown]
# Теперь можно заполнять пропуски по таблице.

# %%
for column in cartype_summary.columns:
    intermediate = data[column]
    intermediate.index = data["MakeModel"]
    intermediate.fillna(cartype_summary[column], inplace=True)
    intermediate.index = data.index
    data[column] = intermediate

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 353693 entries, 0 to 354368
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        353693 non-null  object
#  1   Price              351555 non-null  float64
#  2   VehicleType        346920 non-null  object
#  3   RegistrationYear   353627 non-null  float64
#  4   Gearbox            349644 non-null  object
#  5   Power              347497 non-null  float64
#  6   Model              334158 non-null  object
#  7   Kilometer          353693 non-null  int64
#  8   RegistrationMonth  353693 non-null  int64
#  9   FuelType           346605 non-null  object
#  10  Brand              353693 non-null  object
#  11  Repaired           282775 non-null  object
#  12  DateCreated        353693 non-null  object
#  13  NumberOfPictures   353693 non-null  int64
#  14  PostalCode         353693 non-null  int64
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Согласен с таким заполнением 👍
# </div>

# %% [markdown]
# Теперь пропусков стало существенно меньше.
#
# Остаются два интересующих нас столбца со значительной (>5%) долей пропусков - Repaired и Model.
#
# В столбце Repaired заполним данные случайными флагами так, чтобы после заполнения пропорция сохранилась. Думаю, это весьма валидный подход, т.к. распределение битых машин должно быть относительно равномерным вне зависимости от параметров авто.

# %%
nonrepaired_part = (
    len(data[data["Repaired"] == "no"])
    /
    (len(data[data["Repaired"] == "no"]) + len(data[data["Repaired"] == "yes"]))
)

print("Доля неремонтированных машин в данных: {0:.4f}".format(nonrepaired_part))
# Out:
# Доля неремонтированных машин в данных: 0.8728

# %%
data["Repaired"] = data["Repaired"].fillna(
    pd.Series(np.random.choice(["no", "yes"], size=shape_init[0], p=[nonrepaired_part, 1 - nonrepaired_part]))
)

# %% [markdown]
# Не вижу, как можно относительно просто заполнить модели, поэтому, я думаю, оставить как есть. В любом случае я их буду кодировать, вероятнее всего, через OHE, поэтому, просто NaNам выделится отдельный столбец.
#
# Остальных пропусков немного, их сбросим.

# %%
data = data.dropna(subset=["Price", "VehicleType", "RegistrationYear", "Gearbox", "Power", "FuelType"])

# %%
print(
'''
Удалено строк данных: {0}
Что составляет {1:.2%} от начальных
'''.format(
    shape_init[0] - data.shape[0],
    (shape_init[0] - data.shape[0]) / shape_init[0]
          )
)
# Out:
# Удалено строк данных: 12712
# Что составляет 3.59% от начальных

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 341657 entries, 0 to 354368
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        341657 non-null  object
#  1   Price              341657 non-null  float64
#  2   VehicleType        341657 non-null  object
#  3   RegistrationYear   341657 non-null  float64
#  4   Gearbox            341657 non-null  object
#  5   Power              341657 non-null  float64
#  6   Model              334123 non-null  object
#  7   Kilometer          341657 non-null  int64
#  8   RegistrationMonth  341657 non-null  int64
#  9   FuelType           341657 non-null  object
#  10  Brand              341657 non-null  object
#  11  Repaired           341657 non-null  object
#  12  DateCreated        341657 non-null  object
#  13  NumberOfPictures   341657 non-null  int64
#  14  PostalCode         341657 non-null  int64
# ...

# %% [markdown]
# С заполнением закончили, можно приступать к выделению предикторов и разделением на выборки.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Пропуски успешно обработаны 👍 Модели теперь не будут капризничать)
# </div>

# %% [markdown]
# ### Выделение предикторов и разделение на выборки

# %% [markdown]
# Сначала избавимся от параметров, которые для нас не представляют интереса и не могут испоьзоваться для предсказания:
# - DateCrawled - дата попадения в датасет никак не связана с ценой авто
# - RegistrationMonth - месяц цикличен и, думаю, особого интереса не представляет
# - DateCreated - дата публикации может и позволит улучшить качество обучения модели, но вряд ли позволит улучшить качество предсказаний, т.к. это будет некая экстраполяция.
# - NumberOfPictures - характеристика объявления, а не авто
# - PostalCode - теоретически может быть использована, если ближние значения кода соответствуют ближним точкам в пространстве, но уверенности в этом нет, так что использовать не будем.
# - LastSeen - характеристика пользователя, а не авто
# - MakeModel - служебный столбец, лучше будет использовать раздельно Model и Brand

# %%
features = data.drop([
    "DateCrawled", "RegistrationMonth", "DateCreated", "NumberOfPictures",
    "PostalCode", "LastSeen", "MakeModel", "Price"
], axis=1)

# %%
target = data["Price"]

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Удалить неинформативные признаки - хорошее решение 👍🏻
# </div>

# %% [markdown]
# Предикторы/цели выделили, теперь можно данные делить на обучающую и тестовую выборки.
#
# Делить будем без валидационной выборки, в пропорции 80/20. Гиперпараметры будем подбирать кросс-валидацией.

# %%
seed = 111

# %%
features_train, features_test, target_train, target_test = train_test_split(features, target, test_size=.2, random_state=seed)

# %%
#print(features_train.shape)
#print(target_train.shape)
#print(features_test.shape)
#print(target_test.shape)

# %% [markdown]
# Датасеты разделили, можно переходить к обучению моделей и поиску оптимальных гиперпараметров.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Данные поделены верно, пропорции выбраны адекватные 👍
# </div>

# %% [markdown]
# ## Обучение моделей

# %% [markdown]
# Прежде чем обучать модели, нужно сделать 2 вещи:
# 1. Закодировать категориальные переменные
# 2. Отскейлить имеющиеся данные, т.к. одна из моделей, которую я хочу протестировать - kNN.

# %% [markdown]
# ### Скейлинг и кодировка данных

# %%
numerical_columns = ["RegistrationYear", "Power", "Kilometer"]
categorial_columns = ["VehicleType", "Gearbox", "Model", "FuelType", "Brand", "Repaired"]

transformer_ohe = make_column_transformer(
    (StandardScaler(), numerical_columns),
    (OneHotEncoder(drop="first"), categorial_columns)
)

# %%
transformer_ohe.fit(features_train);

# %%
features_train_transformed_ohe = transformer_ohe.transform(features_train)

# %% [markdown]
# Данные подготовлены, можно обучать модели.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Для линейных моделей прямое кодирование отлично подойдет 👍
# </div>

# %% [markdown]
# ### Базовая модель

# %% [markdown]
# Прежде чем обучать настоящие модели, стоит понять, где проходит граница адекватности для точности. Для этого обучим простую модель.

# %%
def rmse(truths, predictions):
    return mean_squared_error(truths, predictions) ** .5

# %%
baseline_model = GridSearchCV(
    DummyRegressor(),
    param_grid={},
    scoring=make_scorer(rmse, greater_is_better=False),
    n_jobs=-1
)

# %%
# %%time
baseline_model.fit(features_train_transformed_ohe, target_train)
# Out:
# CPU times: user 82 ms, sys: 208 ms, total: 290 ms
# Wall time: 2.16 s
# GridSearchCV(estimator=DummyRegressor(), n_jobs=-1, param_grid={},
#              scoring=make_scorer(rmse, greater_is_better=False))

# %%
baseline_model.best_score_
# Out:
# -4475.443139521303

# %% [markdown]
# Граница адекватности ясна, ожидаю, что RMSE для всех обученных моделей будет ниже.
#
# Еще будем собирать сводную таблицу для финального сравнения.

# %%
models_summary = pd.DataFrame({
    "RMSE":[-baseline_model.best_score_],
    "fit_time":[.766],
    "predict_time":[np.NaN]
                              }
)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Модель обучена корректно 👍
# </div>

# %% [markdown]
# ### Линейная регрессия

# %% [markdown]
# Начнем с самой простой модели - линейной регрессии.

# %%
best_models = {}

# %%
linear_model = GridSearchCV(
    LinearRegression(),
    param_grid={},
    scoring=make_scorer(rmse, greater_is_better=False),
    n_jobs=-1
)

# %%
# %%time
linear_model.fit(features_train_transformed_ohe, target_train)
# Out:
# CPU times: user 14.3 s, sys: 664 ms, total: 15 s
# Wall time: 16.1 s
# GridSearchCV(estimator=LinearRegression(), n_jobs=-1, param_grid={},
#              scoring=make_scorer(rmse, greater_is_better=False))

# %%
linear_model.best_score_
# Out:
# -2776.5989242898972

# %% [markdown]
# Ошибка выше ошибки по условию задания, рассчитаем еще по условию задания время предсказания.

# %%
# %%time
linear_model.predict(features_train_transformed_ohe);
# Out:
# CPU times: user 41 ms, sys: 0 ns, total: 41 ms
# Wall time: 10 ms

# %%
best_models["linear"] = linear_model.best_estimator_

# %%
models_summary = pd.concat(
    [models_summary] +
    [pd.DataFrame({
    "RMSE":[-linear_model.best_score_],
    "fit_time":[13.3],
    "predict_time":[6.98]
                              }
    )]
        )

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Модель обучена корректно 👍
# </div>

# %% [markdown]
# ### K ближайших соседей

# %% [markdown]
# Попробуем kNN.

# %%
#knn_params = {
#    "n_neighbors":range(1, 5)
#}

#knn_model = GridSearchCV(
#    KNeighborsRegressor(),
#    param_grid={},
#    scoring=make_scorer(rmse, greater_is_better=False),
#    n_jobs=-1,
#    verbose=4
#)

# %%
#knn_model = KNeighborsRegressor()

# %%
#%%time
#knn_model.fit(features_train_transformed_ohe, target_train)

# %% [markdown]
# Попробовать не удалось, предсказание даже для одной модели на этих данных очень много времени занимает.
#
# Дальше ее использовать не будем.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Модель обучена корректно 👍
# </div>

# %% [markdown]
# ### Дерево решений

# %% [markdown]
# Попробуем еще дерево решений, оно недолго обучается.
#
# Но модели деревьев работают быстрее с категориальными признаками, закодированными через OrdinalEncoder, а не OHE, поэтому сначала сделаем это.

# %%
transformer_ordinal = make_column_transformer(
    (StandardScaler(), numerical_columns),
    (OrdinalEncoder(encoded_missing_value=-1), categorial_columns)
)

# %%
transformer_ordinal.fit(features_train);

# %%
features_train_transformed_ordinal = transformer_ordinal.transform(features_train)

# %%
tree_params = {
    "max_depth":range(2, 30, 2),
    "random_state":[seed]
}

tree_model = GridSearchCV(
    DecisionTreeRegressor(),
    param_grid=tree_params,
    scoring=make_scorer(rmse, greater_is_better=False),
    n_jobs=-1
)

# %%
# %%time
tree_model.fit(features_train_transformed_ordinal, target_train)
# Out:
# CPU times: user 980 ms, sys: 192 ms, total: 1.17 s
# Wall time: 14.7 s
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'max_depth': range(2, 30, 2), 'random_state': [111]},
#              scoring=make_scorer(rmse, greater_is_better=False))

# %%
tree_model.best_score_
# Out:
# -1958.6968373324562

# %% [markdown]
# Обучение чуть дольше линейной регрессии, но и точность существенно лучше и уже проходит по условию задания.

# %%
tree_model.best_params_
# Out:
# {'max_depth': 14, 'random_state': 111}

# %%
# %%time
tree_model.predict(features_train_transformed_ordinal);
# Out:
# CPU times: user 52.9 ms, sys: 4.01 ms, total: 56.9 ms
# Wall time: 52.5 ms

# %%
best_models["tree"] = tree_model.best_estimator_

# %%
models_summary = pd.concat(
    [models_summary] +
    [pd.DataFrame({
    "RMSE":[-tree_model.best_score_],
    "fit_time":[16.1],
    "predict_time":[73.5]
                              }
    )]
        )

# %% [markdown]
# Случайный лес пробовать не будем, уже одно дерево работает весьма долго.
#
# Переходим к градиентному бустингу.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Модель обучена корректно 👍
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌ Замечание:</b>
#
# Для моделей, основанных на деревьях решений, лучше использовать порядковое кодирование (OrdinalEncoder). Это должно ускорить их работу. Так как при большом количестве признаков, модель будет долго искать оптимальный сплит.
# </div>

# %% [markdown]
# <div style="background: #91ff7e; padding: 5px; border: 1px solid Black; border-radius: 5px;">
#     КОММЕНТАРИЙ СТУДЕНТА V1
#     <br/>
#     Ага, понял. <br>
#     Добавил второй датасет, закодированный через OrdinalEncoder, поменял на него обучение на модели дерева, действительно, работать стало сильно шустрее. <br>
#     Буду иметь в виду. <br>
# </div>

# %% [markdown]
# ```python
# # порядковое кодирование (для "деревянных моделей")
# encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=9999)
# cat_columns = [список всех категориальных признаков]
# encoder.fit(features_train[cat_columns])
#
# features_train_ord = features_train.copy()
# features_valid_ord = features_valid.copy()
# features_test_ord = features_test.copy()
#
# features_train_ord[cat_columns] = encoder.transform(features_train_ord[cat_columns])
# features_valid_ord[cat_columns] = encoder.transform(features_valid_ord[cat_columns])
# features_test_ord[cat_columns] = encoder.transform(features_test_ord[cat_columns])
# ```

# %% [markdown]
# ### Градиентный бустинг

# %%
gbm_params = {
    "n_estimators":range(50, 150, 25),
    "max_depth":range(5, 55, 10),
    "reg_lambda":np.arange(0, .5, .1),
    "random_state":[seed]
}

gbm_model = GridSearchCV(
    LGBMRegressor(),
    param_grid=gbm_params,
    scoring=make_scorer(rmse, greater_is_better=False),
    cv=4,
    n_jobs=-1
)

# %%
# %%time
gbm_model.fit(features_train_transformed_ordinal, target_train)
# Out:
# CPU times: user 9.76 s, sys: 1.35 s, total: 11.1 s
# Wall time: 4min 35s
# GridSearchCV(cv=4, estimator=LGBMRegressor(), n_jobs=-1,
#              param_grid={'max_depth': range(5, 55, 10),
#                          'n_estimators': range(50, 150, 25),
#                          'random_state': [111],
#                          'reg_lambda': array([0. , 0.1, 0.2, 0.3, 0.4])},
#              scoring=make_scorer(rmse, greater_is_better=False))

# %%
gbm_model.best_score_
# Out:
# -1781.9671670003663

# %%
gbm_model.best_params_
# Out:
# {'max_depth': 15,
#  'n_estimators': 125,
#  'random_state': 111,
#  'reg_lambda': 0.30000000000000004}

# %% [markdown]
# Первые впечатления - работает невероятно быстро.
#
# Весьма ощутимое улучшение относительно дерева решений в плане ошибки.
#
# Дальше анализ моделей и проверка на тестовой выборке.

# %%
# %%time
gbm_model.predict(features_train_transformed_ordinal);
# Out:
# CPU times: user 4.26 s, sys: 83.9 ms, total: 4.34 s
# Wall time: 614 ms

# %%
best_models["gbm"] = gbm_model.best_estimator_

# %%
models_summary = pd.concat(
    [models_summary] +
    [pd.DataFrame({
    "RMSE":[-gbm_model.best_score_],
    "fit_time":[252],
    "predict_time":[391]
                              }
    )]
        )

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Модель обучена корректно 👍
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>⚠️ Совет:</b>
#
# У бустингов под капотом есть возможность кодировать категориальные признаки:
#
# 1. CatBoost. Нужно категориальные признаки передать в параметр `cat_features`.
# 2. LightGBM. Нужно изменить тип данных категориальных признаков с `object` на `category`.
#
# Это должно ускорить их работу. Так как при большом количестве признаков, модель будет долго искать оптимальный сплит.
# </div>

# %% [markdown]
# ## Анализ моделей

# %% [markdown]
# ### Сравнение

# %% [markdown]
# Посмотрим сводную таблицу обученных моделей.

# %%
models_summary.index = ["DummyRegressor", "LinearRegression", "DecisionTree", "LGBMRegressor"]

# %%
pd.set_option('display.precision', 2)
display(models_summary)
# Out:
#                      RMSE  fit_time  predict_time
# DummyRegressor    4475.44      0.77           NaN
# LinearRegression  2776.60     13.30          6.98
# DecisionTree      1958.70     16.10         73.50
# LGBMRegressor     1781.97    252.00        391.00

# %% [markdown]
# Единицы измерения:
# * Время обучения - [с]
# * Время предсказания - [мс]

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Молодец, что для сравнения моделей заносишь их в общий датафрейм 👍
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>⚠️ Совет:</b>
#
# Из того же GridSearchCV мы можем получить время обучения и время предсказания)
#
# В атрибуте `cv_results_` есть среднее время обучения и среднее время предсказания для всех комбинаций.
# </div>

# %% [markdown]
# ### Промежуточные выводы

# %% [markdown]
# * Все обученные модели показали точность (RMSE) выше простой модели.
# * Модель линейной регрессии показала точность ниже, чем по условию задания (RMSE > 2500).
# * Модель градиентного бустинга показала наибольшую точность, но вместе с этим максимальное время обучения и предсказания, при этом время предсказания существенно выше, чем у остальных моделей.
#
# Время обучения и предсказания визуально представлены на графике:

# %%
fig, axs = plt.subplots(1, 3, figsize=(24, 6))

axs[0].bar(x=models_summary.index, height=models_summary["RMSE"])
axs[1].bar(x=models_summary.index, height=models_summary["fit_time"])
axs[2].bar(x=models_summary.index, height=models_summary["predict_time"])

axs[0].set_title("RMSE")
axs[1].set_title("Время обучения (wall-clock), с")
axs[2].set_title("Время предсказания (wall-clock), мс");

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Вывод соответствует анализу 👍 Значит рекомендуем заказчику LGBM
# </div>

# %% [markdown]
# ### Проверка на тестовой выборке

# %% [markdown]
# Наилучшая модель определена, это модель градиентного бустинга.
#
# Теперь нужно проверить ее на тестовой выборке.

# %%
## Скейлинг + кодировка
features_test_transformed = transformer_ordinal.transform(features_test)

# %%
model = best_models["gbm"]

predictions_test = model.predict(features_test_transformed)

print("RMSE на тестовой выборке: {0:.1f}".format(rmse(target_test, predictions_test)))
# Out:
# RMSE на тестовой выборке: 1804.2

# %% [markdown]
# RMSE на тестовой выборке и при кросс-валидации сравнимы, модель можно рекомендовать к использованию.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Отличный результат 👍
# </div>

# %% [markdown]
# ## Выводы

# %% [markdown]
# * Исходные данные были обработаны и разделены на обучающую и тестовую выборку в пропорции 80/20. Подбор гиперпараметров осуществлялся кросс-валидацией на обучающей выборке.
# * Были обучены 3 типа моделей: линейная регрессия, дерево решений, градиентный бустинг.
# * Все 3 модели показали RMSE меньше, чем у простой модели.
# * Модель линейной регресси показала RMSE выше, чем по условию задания (2777 > 2500).
# * Наилучшую точность показала модель градиентного бустинга ($RMSE_{cv}$ = 1780).
# * Линейная регрессия показала минимальное время обучения и предсказания, в то время как, градиентный бустинг показал максимальное время обучения и предсказания.
# * Сравнение моделей в табличном и графчиеском виде представлено ниже:

# %% [markdown]
# ![summary_chart.png](attachment:summary_chart.png)

# %% [markdown]
# ![summary_table.png](attachment:summary_table.png)

# %% [markdown]
# * Модель градиентного бустинга прошла проверку на тестовой выборке и показала значения RMSE, сравнимые (1782) с RMSE при кросс-валидации (1804).
# * Модель **градиентного бустинга рекомендуется** к дальнейшему использованию. Модель хранится в переменной *model*.
# * Модель kNN не может использоваться из-за чрезмерно длительного времени предсказания.

# %% [markdown]
# <div style="background: #91ff7e; padding: 5px; border: 1px solid Black; border-radius: 5px;">
#     КОММЕНТАРИЙ СТУДЕНТА V1
#     <br/>
#     Обновил графики, таблицу и цифры в выводе с учетом изменений.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✔️ Успех:</b>
#
# Вывод соответствует исследованию 👍
# </div>

# %% [markdown]
# # <font color='orange'>Общее впечатление</font>
# * Этот проект выполнен очень хорошо
# * Видно, что приложено много усилий
# * Молодец, что структурируешь ноутбук, приятно проверять такие работы
# * У тебя чистый и лаконичный код
# * Мне было интересно читать твои промежуточные выводы
# * Твой уровень подачи материала находится на высоком уровне
# * Исправь, пожалуйста, мои замечания. Затем отправляй на повторную проверку
# * Жду новую версию проекта 👋

# %% [markdown]
# # <font color='orange'>Рекомендации 🔥</font>
# * Доступное объяснение про работу градиентного бустинга <a href='https://www.youtube.com/watch?v=ZNJ3lKyI-EY&t=995s'>ссылка</a>
# * После просмотра видео можешь почитать статью про ансамбли и бустинги <a href='https://habr.com/ru/company/ods/blog/645887/'>ссылка</a>
# * Статья на Хабре представляет краткое введение в алгоритмы бустинга и описывает их принципы работы <a href='https://habr.com/ru/company/ods/blog/327250/'>ссылка</a>
# * Подбор гиперпараметров для CatBoost <a href='https://habr.com/ru/company/otus/blog/527554/'>ссылка</a>
# * Подбор гиперпараметров для LightGBM <a href='https://programmersought.com/article/40776531516/'>ссылка</a>
# * Разумные способы кодирования категориальных данных для машинного обучения <a href='https://machinelearningmastery.ru/smarter-ways-to-encode-categorical-data-for-machine-learning-part-1-of-3-6dca2f71b159/'>ссылка</a>
# * Статья про "непонятную" метрику ROC-AUC <a href='https://dyakonov.org/2017/07/28/auc-roc-площадь-под-кривой-ошибок/'>ссылка</a>
# * Хочешь подтянуть математику для DS?) <a href='https://academy.stepik.org/math-for-data-science'>ссылка</a>
# * Также есть курс по математике от ЯП <a href='https://practicum.yandex.ru/math-for-da-ds/'>ссылка</a>
# * В нашем деле нужно быть всегда в курсе всех новинок, новостей и тд, вот тут публикуют новости в области DS <a href='https://www.infoq.com/data-analysis/news/'>ссылка</a>
# * Всем аналитикам данных рекомендую книгу Даниела Канемана "Думай медленно, решай быстро"
